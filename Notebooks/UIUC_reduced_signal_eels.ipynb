# %% [markdown]
# # Utility/imports

# %% [markdown]
# data used: https://doi.org/10.13012/B2IDB-8188066_V1

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from tqdm import tqdm

import h5py

import holoviews as hv
import panel as pn

hv.extension('bokeh')
pn.extension('bokeh')

import h5py

import torch
import glob

import sys
sys.path.append('..') # path to the src directory
sys.path.append('/home/xinqiao/new_mount/gaussian sampler/M3Learning-Util/src')
sys.path.append('/home/xinqiao/new_mount/gaussian sampler/AutoPhysLearn/src')

import matplotlib.pyplot as plt
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='8525f39a-4d86-4780-909f-0e148ac93e46'>
#   <div id="f97b9620-de16-420b-93c3-8266c51e5b78" data-root-id="8525f39a-4d86-4780-909f-0e148ac93e46" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"4a3a5ba2-57f8-431b-92eb-bdf06c1a662f":{"version":"3.7.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"8525f39a-4d86-4780-909f-0e148ac93e46"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"2f1b284e-0558-4868-969b-4ba6ea3a7d58","attributes":{"plot_id":"8525f39a-4d86-4780-909f-0e148ac93e46","comm_id":"ef2d9b5b315a4692b242fb342d3bb278","client_comm_id":"4906d80e20584c86bd5f80063b8ddd15"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"nam ...
#   var render_items = [{"docid":"4a3a5ba2-57f8-431b-92eb-bdf06c1a662f","roots":{"8525f39a-4d86-4780-909f-0e148ac93e46":"f97b9620-de16-420b-93c3-8266c51e5b78"},"root_ids":["8525f39a-4d86-4780-909f-0e148ac93e46"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <a href="https://holoviews.org" target="_blank" title="HoloViews 1.21.0">
#   <img src='...' style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
# </a>
#
#
# <a href="https://bokeh.org" target="_blank" title="Bokeh 3.7.3">
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'>
#   </img>
# </a>
#
#
#
#
#
#
#
# <span style="float: left; margin-left: 5px; line-height: 15px; cursor: pointer; opacity: 0.7;"
#       onmouseover="this.style.opacity='1'"
#       onmouseout="this.style.opacity='0.7'"
#       title="Extension loaded. This cell output contains code that enables plot interactivity, it should not be removed.">ⓘ</span>
# </div>
# WARNING:param.panel_extension: bokeh extension not recognized and will be skipped.
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# ## write low-signal data (todo)

# %%
import hyperspy.api as hs

datapath = '/home/xinqiao/new_mount/gaussian sampler/EELS_datasets/'
file = hs.load(datapath + 'U-NP_ll.dm4')
# Out:
# WARNING | Hyperspy | `signal_type='EELS'` not understood. See `hs.print_known_signal_types()` for a list of installed signal types or https://github.com/hyperspy/hyperspy-extensions-list for the list of all hyperspy extensions providing signals. (hyperspy.io:745)
# WARNING | Hyperspy | `signal_type='EELS'` not understood. See `hs.print_known_signal_types()` for a list of installed signal types or https://github.com/hyperspy/hyperspy-extensions-list for the list of all hyperspy extensions providing signals. (hyperspy.io:745)

# %%
# file.axes_manager.indices = (3, 12)  # Jump to specific coordinates
# file.plot()

# %% [markdown]
# ## test dropping out

# %%
# TODO: loop through and generate log2 spaced noise percentage 
file.data[np.isnan(file.data)] = 0

all_count = file.data.sum(axis=2).reshape(-1,1)
cumsum = np.cumsum(file.data.astype('float64'),axis=2).reshape(-1,file.data.shape[2])

keep = .0003
keeping = [np.random.randint(0,count,size=int(keep*count)) for count in all_count]
print("keeping counts about:", int(keep*all_count[10]))
keep_bins = [np.searchsorted(cumsum[i], drop) for i, drop in enumerate(keeping)]

bins_counts = [np.unique(bin, return_counts=True) for bin in keep_bins]

new_data = np.zeros((file.data.shape[0]*file.data.shape[1],file.data.shape[2]))
for i, (b, c) in enumerate(bins_counts):
    new_data[i][b] = c

new_file = file.copy()
new_file.data = new_data.reshape(file.data.shape)
# Out:
# keeping counts about: 57
# /tmp/ipykernel_2171220/1444608948.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   keeping = [np.random.randint(0,count,size=int(keep*count)) for count in all_count]
# /tmp/ipykernel_2171220/1444608948.py:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("keeping counts about:", int(keep*all_count[10]))

# %%
file.axes_manager.indices = (3, 12)  # Jump to specific coordinates
new_file.plot()
# Out:
# WARNING | Hyperspy | `signal_type='EELS'` not understood. See `hs.print_known_signal_types()` for a list of installed signal types or https://github.com/hyperspy/hyperspy-extensions-list for the list of all hyperspy extensions providing signals. (hyperspy.io:745)
# WARNING | Hyperspy | `signal_type='EELS'` not understood. See `hs.print_known_signal_types()` for a list of installed signal types or https://github.com/hyperspy/hyperspy-extensions-list for the list of all hyperspy extensions providing signals. (hyperspy.io:745)

# %% [markdown]
# ## scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
training_data = scaler.fit_transform(new_file.data.reshape(-1,new_file.data.shape[2]).T).T

# %%
import matplotlib.pyplot as plt
plt.plot(training_data[39])

# %% [markdown]
# ## custom dataloader

# %%
from sklearn.preprocessing import MinMaxScaler

class test_dataset(torch.utils.data.Dataset):
    def __init__(self, file, shape=[30,30,2048], scale=True, sample_percentage = 0.01):
        '''dset is x*y,spec_len'''
        self.file_ = file
        self.shape = file.data.shape
        # self.data_ = self.file.data.reshape(shape[0]*shape[1], -1)
        self.sample_percentage = sample_percentage
        self.lower_snr(sample_percentage)
        
        if scale: self.scale()
        else: self.data = self.file.data
    
    def __len__(self): return (self.shape[0]*self.shape[1])

    def __getitem__(self, idx):
        return idx, self.data[idx]
    
    def lower_snr(self, sample_percentage):
    # TODO: loop through and generate log2 spaced noise percentage 
        all_count = self.file_.data.sum(axis=2).reshape(-1,1)
        cumsum = np.cumsum(self.file_.data.astype('float64'),axis=2).reshape(-1,self.file_.data.shape[2])

        keeping = [np.random.randint(0,count,size=int(sample_percentage*count)) for count in all_count]
        print("keeping counts about:", int(sample_percentage*all_count[10]))
        keep_bins = [np.searchsorted(cumsum[i], drop) for i, drop in enumerate(keeping)]
        bins_counts = [np.unique(bin, return_counts=True) for bin in keep_bins]

        new_data = np.zeros((self.shape[0]*self.shape[1],self.shape[2]))
        for i, (b, c) in enumerate(bins_counts): new_data[i][b] = c

        self.file = self.file_.copy()
        self.file.data = new_data.reshape(file.data.shape)
        
            
    def getitem_zero_dset(self,idx):
        return self.data[idx]
        
    def scale(self):
        scaler = MinMaxScaler()
        self.data = scaler.fit_transform(self.file.data.reshape(-1,self.shape[2]).T).T

# %%
dset = test_dataset(file, sample_percentage=0.001)
# Out:
# keeping counts about: 192
# /tmp/ipykernel_2342771/489152712.py:25: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   keeping = [np.random.randint(0,count,size=int(sample_percentage*count)) for count in all_count]
# /tmp/ipykernel_2342771/489152712.py:26: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("keeping counts about:", int(sample_percentage*all_count[10]))

# %%
dset.file.plot()
# Out:
# WARNING | Hyperspy | `signal_type='EELS'` not understood. See `hs.print_known_signal_types()` for a list of installed signal types or https://github.com/hyperspy/hyperspy-extensions-list for the list of all hyperspy extensions providing signals. (hyperspy.io:745)
# WARNING | Hyperspy | `signal_type='EELS'` not understood. See `hs.print_known_signal_types()` for a list of installed signal types or https://github.com/hyperspy/hyperspy-extensions-list for the list of all hyperspy extensions providing signals. (hyperspy.io:745)

# %% [markdown]
# ## Fitter

# %%
from Gaussian_Sampler.models.pv_fitter import pseudovoigt_1D_fitters_new
fitter = pseudovoigt_1D_fitters_new(limits = [1,1,2048])
# Out:
# /home/xinqiao/anaconda3/envs/gaussian_sampler/lib/python3.13/site-packages/datafed_torchflow/computer.py:5: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %% [markdown]
# ## Dataset

# %%
# from Gaussian_Sampler.data.datasets import Fake_PV_Dataset
# datapath = '/home/xinqiao/new_mount/gaussian sampler/'

# dset = Fake_PV_Dataset(shape=(new_file.data.shape),
#                        save_folder=datapath,
#                        pv_param_classes={'h':[5,6,9,10,7], 'E':[0,100,400,500,700], 'F':[50,50,70,90,90], 'nu':[0.7,0.7,0.7,0.4,0.4]},
#                        pv_fitter=fitter,
#                     #    scaled=True, # make sure to change 
#                        noise_level=0, # make sure to change in other places
#                        # TEST: scaling kernel size
#                        scaling_kernel_size=1,
#                        overwrite=False
#                        )

# %% [markdown]
# ## sampler

# %%
from Gaussian_Sampler.data.custom_sampler import Gaussian_Sampler
sampler = Gaussian_Sampler(dset, batch_size=50, orig_shape=dset.shape, 
                           # TEST: gaussian std
                           gaussian_std=3, 
                           # TEST: num neighbors
                           num_neighbors=10)
batch_inds = next(iter(sampler))

# %% [markdown]
# ## visualize

# %%
# # for visualizing gaussian sampled points
# plt.figure(figsize=(6,6), facecolor="none")   # transparent figure
# ax = plt.gca()
# ax.set_facecolor("white")                     # keep axes background white

# plt.scatter([b//100 for b in batch_inds], [b%100 for b in batch_inds], s=35, c='r')
# plt.xlim(0, 100)
# plt.ylim(0, 100)
# ax.set_aspect('equal', adjustable='box')
# plt.xticks([])
# plt.yticks([])

# plt.savefig("scatter_plot.svg", format="svg", transparent=True)

# %%
from Gaussian_Sampler.viz.hv_viz import Fake_PV_viz

viz = Fake_PV_viz(dset, sampler)

# %% [markdown]
# #### The following cell displays an example of the training data
# - Left side is the image dimension. The red spot is the location where the signal is displayed.
# - Right side is the spectral dimension. The black line is the spectra where the image is displayed. The red signal is signal without noise. The blue signal is with uniform gaussian noise.

# %%
input_viz = viz.layout_input()
# input_viz.show(port=5006, websocket_origin="*")
input_viz
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'9dd35eaa-e963-467c-ac2d-6f3d1abb3f3e': {'version…

# %%
# input_viz.stop()
input_viz.clear()
# Out:
# [Row
#      [0] IntSlider(end=19, name='Noise std', value=4)
#      [1] IntSlider(end=749, name='spectral value', value=123),
#  Row
#      [0] IntSlider(end=99, name='x', value=24)
#      [1] IntSlider(end=99, name='y', value=35),
#  HoloViews(Layout)]

# %% [markdown]
# #### The following cell displays signals from the gaussian sampled batches
# - Checkboxes correspond to the sampled minibatches. Each minibatch has a corresponding color
# - Left side is the image dimension. The red spot is the location where the signal is displayed. The colored spots are the sampled minibatch
# - Right side is the spectral dimension. The black line is the spectra where the image is displayed. The red signal is signal without noise. The blue signal is with uniform gaussian noise. The color signals are corresponding minibatches, averaged out.

# %%
batch_viz = viz.layout_batch()
batch_viz
# pane = batch_viz.show(port=5006, )
                      #websocket_origin="*",threaded=True)
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'efafb393-3d28-4031-b380-1674fd311a0f': {'version…

# %%
batch_viz.clear()
# Out:
# [Row
#      [0] IntSlider(end=19, name='Noise std')
#      [1] IntSlider(end=749, name='spectral value'),
#  Row
#      [0] IntSlider(end=99, name='x', value=25)
#      [1] IntSlider(end=99, name='y', value=25),
#  Row
#      [0] CheckBoxGroup(inline=True, name='Batch Checkboxes', options=[0, 1, 2, 3, 4, ...], value=[0, 1, 2, 3, 4, ...]),
#  HoloViews(Layout)]

# %% [markdown]
# ## test model

# %%
from Gaussian_Sampler.models.pv_fitter import Fitter_AE, pseudovoigt_1D_fitters, pseudovoigt_1D_fitters_new
from autophyslearn.spectroscopic.nn import block_factory, Conv_Block, FC_Block
from autophyslearn.spectroscopic.nn import Multiscale1DFitter
from Gaussian_Sampler.data.custom_sampler import Gaussian_Sampler



num_fits = 4 # number of curves to sum up
num_params = 4 # number of parameters to fit
# dset = training_data#.reshape(30,30,-1)

fitter = Fitter_AE(function=pseudovoigt_1D_fitters_new,
                   dset=dset,
                   num_params=num_params,
                   num_fits=num_fits,
                   input_channels = 1,
                   learning_rate=3e-5,
                   device='cuda:0',
                   encoder = Multiscale1DFitter,
                   encoder_params = {
                       "model_block_dict": { # factory wrapper for blocks
                            "hidden_x1": block_factory(Conv_Block)(output_channels_list=[8,4], 
                                                                    kernel_size_list=[5,3], 
                                                                    pool_list=[128], 
                                                                    max_pool=False),
                            "hidden_xfc": block_factory(FC_Block)(output_size_list=[64,32]),
                            "hidden_x2": block_factory(Conv_Block)(output_channels_list=[4,4,4], 
                                                                    kernel_size_list=[3,3,3], 
                                                                    pool_list=[8,4], 
                                                                    max_pool=True),
                            "hidden_embedding": block_factory(FC_Block)(output_size_list=[8*num_fits,num_params*num_fits], last=True),
                        },
                        # TEST: LIMITS,
                        "skip_connections": {'hidden_xfc': 'hidden_embedding'},
                        "function_kwargs": {'limits': [1,dset.shape[-1],dset.shape[-1]] }
                    },
                    checkpoint_folder='../../checkpoints/reduced_signal/',
                    sampler = Gaussian_Sampler,
                    sampler_params = {'dset': dset, 
                                      'batch_size': 128, 
                                      'gaussian_std': 5, 
                                      'orig_shape': dset.shape, 
                                      'num_neighbors': 10, },
                )

# %% [markdown]
# ### make graph for model

# %%
# from torchviz import make_dot
# x = torch.Tensor(dset[2346][1]).reshape(-1,1,dset.spec_len).float().to('cuda:0')
# # Generate the dot graph
# dot = make_dot(fitter.encoder(x), params=dict(fitter.encoder.named_parameters()))

# # Save the graph as a PDF
# dot.render("model_visualization", format="svg")

# %%
from torchview import draw_graph
x = torch.Tensor(dset[2346][1]).reshape(-1,1,dset.spec_len).float().to('cuda:0')

model_graph = draw_graph(fitter.encoder, input_data=x,
                         expand_nested=True,
                         hide_module_function=True,
                         hide_inner_tensors=True
                         );

# model_graph = draw_graph(fitter.encoder, input_data=x, 
#                          save_graph=True,
#                          filename="model_visualization_torchview",
#                          directory="./",
#                          format="png")

model_graph.visual_graph
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 from torchview import draw_graph
# ----> 2 x = torch.Tensor(dset[2346][1]).reshape(-1,1,dset.spec_len).float().to('cuda:0')
#       4 model_graph = draw_graph(fitter.encoder, input_data=x,
#       5                          expand_nested=True,
#       6                          hide_module_function=True,
#       7                          hide_inner_tensors=True
#       8                          );
#      10 # model_graph = draw_graph(fitter.encoder, input_data=x,
#      11 #                          save_graph=True,
#      12 #                          filename="model_visualization_torchview",
#      13 #                          directory="./",
#      14 #                          format="png")
#
# Cell In[8], line 10, in test_dataset.__getitem__(self, idx)
#       9 def __getitem__(self, idx):
# ---> 10     return idx, self.data[idx]
#
# IndexError: index 2346 is out of bounds for axis 0 with size 900

# %% [markdown]
# ### Train model for several epochs

# %%
fitter.train(epochs=11,save_every=10)
# Out:
# /home/xinqiao/new_mount/gaussian sampler/checkpoints/reduced_signal
#   0%|          | 0/7 [00:00<?, ?it/s]
# /home/xinqiao/new_mount/gaussian sampler/Gaussian_Sampler/Notebooks/../Gaussian_Sampler/models/pv_fitter.py:581: UserWarning: Using a target size (torch.Size([128, 2048])) that is different to the input size (torch.Size([2048])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   else:
#  86%|████████▌ | 6/7 [00:00<00:00, 77.87it/s]
# Epoch: 000/011 | Train Loss: 0.0202
# .............................
#  86%|████████▌ | 6/7 [00:00<00:00, 80.73it/s]
# Epoch: 001/011 | Train Loss: 0.0072
# .............................
#  86%|████████▌ | 6/7 [00:00<00:00, 82.16it/s]
# Epoch: 002/011 | Train Loss: 0.0026
# .............................
#  86%|████████▌ | 6/7 [00:00<00:00, 84.27it/s]
# Epoch: 003/011 | Train Loss: 0.0021
# .............................
#  86%|████████▌ | 6/7 [00:00<00:00, 110.29it/s]
# Epoch: 004/011 | Train Loss: 0.0020
# .............................
#  86%|████████▌ | 6/7 [00:00<00:00, 104.57it/s]
# Epoch: 005/011 | Train Loss: 0.0019
# .............................
#  86%|████████▌ | 6/7 [00:00<00:00, 95.29it/s]
# Epoch: 006/011 | Train Loss: 0.0019
# .............................
#  86%|████████▌ | 6/7 [00:00<00:00, 110.01it/s]
# Epoch: 007/011 | Train Loss: 0.0019
# .............................
#  86%|████████▌ | 6/7 [00:00<00:00, 112.31it/s]
# Epoch: 008/011 | Train Loss: 0.0019
# .............................
#  86%|████████▌ | 6/7 [00:00<00:00, 104.42it/s]
# Epoch: 009/011 | Train Loss: 0.0019
# .............................
#  86%|████████▌ | 6/7 [00:00<00:00, 112.52it/s]
# Epoch: 010/011 | Train Loss: 0.0019
# .............................

# %%
x,y,s = 10,5,210
i = x*30+y

fig, ax = plt.subplots(1,2)
ax[0].plot(dset[i][1])
ax[0].axvline(s)

ax[1].imshow(dset[:,s][1].reshape(30,30))
ax[1].scatter(x,y,color='red')

# %%
fit, params = fitter.encoder(torch.Tensor(dset[:][1].reshape(dset.shape[0]*dset.shape[1], 1, -1)).to('cuda:0'))
fit = fit.cpu().detach().numpy()
params = params.cpu().detach().numpy()

# %%
params.shape
# Out:
# (900, 4, 4)

# %%
fig, ax = plt.subplots(4,2)
for f in range(4):
    ax[f,0].plot(fit[i,f])
    ax[f,0].axvline(s)

    ax[f,1].imshow(fit[:,f,s].reshape(30,30))
    ax[f,1].scatter(x,y,color='red')

# %%
param_labels = ['a', 'x', 'w', '$\mu$']
fig, ax = plt.subplots(4,4)
for f in range(4):
    for p in range(4):
        ax[f,p].imshow(params[:,f,p].reshape(30,30))
        ax[f,p].scatter(x,y,color='red')
        ax[f,p].set_title(param_labels[p])
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_2342771/1161297400.py:1: SyntaxWarning: invalid escape sequence '\m'
#   param_labels = ['a', 'x', 'w', '$\mu$']

# %%
from torchview import draw_graph
x = torch.Tensor(dset[2346][1]).reshape(-1,1,dset.spec_len).float().to('cuda:0')

model_graph = draw_graph(fitter.encoder, input_data=x)

# model_graph = draw_graph(fitter.encoder, input_data=x, 
#                          save_graph=True,
#                          filename="model_visualization_torchview",
#                          directory="./",
#                          format="png")

model_graph.visual_graph
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from torchview import draw_graph
#       2 x = torch.Tensor(dset[2346][1]).reshape(-1,1,dset.spec_len).float().to('cuda:0')
#       4 model_graph = draw_graph(fitter.encoder, input_data=x)
#
# ModuleNotFoundError: No module named 'torchview'

# %%
# import numpy as np

# def draw_m_in_array(size_=100):
#     arr_ = np.zeros((size_, size_), dtype=int)
#     w=size_//10
#     size=size_//2
#     arr = np.zeros((size, size), dtype=int)

#     for i in range(size):
#         # Left vertical line
#         arr[i, 0:w] = 1
#         # Right vertical line
#         arr[i, size-w:size] = 1
#         # Diagonal from left to middle
#         if w <= i < size // 2:
#             arr[i-w:i+w,i] = 1
#             # Diagonal from right to middle
#             arr[i-w:i+w, size-(i+1)] = 1
#         arr_[size_//4:size_//4+size,size_//4:size_ //4+size] = arr
#     return arr_

# m_array = draw_m_in_array()
# # plt.imshow(m_array)

# %%
# fixed pooling
import matplotlib.pyplot as plt
plt.clf()
test_inds= [10,923,2346,3456,5873,7889,8245,9357,9795]
# batch = next(iter(fitter.dataloader))
# print(batch[1].shape)

# dset.noise_ = 2

test_batch = torch.Tensor(dset[test_inds][1]).reshape(-1,1,dset.spec_len).float().to('cuda:0')
out = fitter.encoder(test_batch.to('cuda:0'))
# print(out[0].shape)
px = 0
fig, ax = plt.subplots(3,3,figsize=(10,10))
ax=ax.flatten()
fig.suptitle(f'Gaussian sampler: noise {dset.noise_}, scaling kernel size {dset.scaling_kernel_size}')
lines = []


for i,ind in enumerate(test_inds):
    a = ax[i].plot(test_batch[i].cpu().detach().numpy().flatten(), label='input')
    if i==0: lines.append(a[0])
    for f in range(out[0].shape[1]):
        a = ax[i].plot(out[0][i,f].cpu().detach().numpy(),'-.', linewidth=0.5, label=f'fit {f}')
        if i==0: lines.append(a[0]) 
    a = ax[i].plot(out[0][i].sum(dim=0).cpu().detach().numpy(), 'k--', label='sum')
    if i==0: lines.append(a[0])


dset.noise_ = 0
for i,ind in enumerate(test_inds):
    a = ax[i].plot(dset[ind][1], label='0-noise')
    ax[i].set_ylim(0, 1)
    if i==0: lines.append(a[0])

ax[0].legend(handles=lines, loc='upper right')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       4 test_inds= [10,923,2346,3456,5873,7889,8245,9357,9795]
#       5 # batch = next(iter(fitter.dataloader))
#       6 # print(batch[1].shape)
#       7
#       8 # dset.noise_ = 2
# ---> 10 test_batch = torch.Tensor(dset[test_inds][1]).reshape(-1,1,dset.spec_len).float().to('cuda:0')
#      11 out = fitter.encoder(test_batch.to('cuda:0'))
#      12 # print(out[0].shape)
#
# NameError: name 'torch' is not defined

# %%
# fixed pooling
import matplotlib.pyplot as plt
plt.clf()
test_inds= [10,923,2346,3456,5873,7889,8245,9357,9795]
# batch = next(iter(fitter.dataloader))
# print(batch[1].shape)

# dset.noise_ = 2

test_batch = torch.Tensor(dset[test_inds][1]).reshape(-1,1,dset.spec_len).float().to('cuda:0')
out = fitter.encoder(test_batch.to('cuda:0'))
# print(out[0].shape)
px = 0
fig, ax = plt.subplots(3,3,figsize=(10,10))
ax=ax.flatten()
fig.suptitle(f'with batch norm after whole blocks: Random sampler: noise {dset.noise_}, scaling kernel size {dset.scaling_kernel_size}')
lines = []


for i,ind in enumerate(test_inds):
    a = ax[i].plot(test_batch[i].cpu().detach().numpy().flatten(), label='input')
    if i==0: lines.append(a[0])
    for f in range(out[0].shape[1]):
        a = ax[i].plot(out[0][i,f].cpu().detach().numpy(),'-.', linewidth=0.5, label=f'fit {f}')
        if i==0: lines.append(a[0]) 
    a = ax[i].plot(out[0][i].sum(dim=0).cpu().detach().numpy(), 'k--', label='sum')
    if i==0: lines.append(a[0])


dset.noise_ = 0
for i,ind in enumerate(test_inds):
    a = ax[i].plot(dset[ind][1], label='0-noise')
    ax[i].set_ylim(0, 1)
    if i==0: lines.append(a[0])

ax[0].legend(handles=lines, loc='upper right')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 16
#      14 fig, ax = plt.subplots(3,3,figsize=(10,10))
#      15 ax=ax.flatten()
# ---> 16 fig.suptitle(f'with batch norm after whole blocks: Random sampler: noise {dset.noise_}, scaling kernel size {dset.scaling_kernel_size}')
#      17 lines = []
#      20 for i,ind in enumerate(test_inds):
#
# File ~/new_mount/gaussian sampler/Gaussian_Sampler/Notebooks/../Gaussian_Sampler/data/datasets.py:79, in Fake_PV_Dataset.scaling_kernel_size(self)
#      78 @property
# ---> 79 def scaling_kernel_size(self): return self._scaling_kernel_size
#
# AttributeError: 'Fake_PV_Dataset' object has no attribute '_scaling_kernel_size'

# %%
test_batch.shape

# %%
# # tanh A activation
# import matplotlib.pyplot as plt
# import torch.nn as nn
# plt.clf()
# test_inds= [10,923,2346,3456,5873,7889,8245,9357,9795]
# # batch = next(iter(fitter.dataloader))
# # print(batch[1].shape)

# dset.noise_ = 5
# test_batch = torch.Tensor(dset[test_inds][1]).reshape(-1,1,dset.spec_len).float().to('cuda:0')
# out = fitter.encoder(test_batch.to('cuda:0'))
# # print(out[0].shape)
# px = 0
# fig, ax = plt.subplots(3,3,figsize=(10,10))
# ax=ax.flatten()
# fig.suptitle(f'Random sampler: noise {dset.noise_}, scaling kernel size {dset.scaling_kernel_size}')
# lines = []

# # Create MSE loss function
# mse_loss = nn.MSELoss()

# # Calculate MSE between input and output
# mse = mse_loss(test_batch.flatten(), out[0].flatten())
# print(f"Mean Squared Error: {mse.item()}")   


# for i,ind in enumerate(test_inds):
#     a = ax[i].plot(test_batch[i].cpu().detach().numpy().flatten(), label='input')
#     if i==0: lines.append(a[0])
#     for f in range(out[0].shape[1]):
#         a = ax[i].plot(out[0][i,f].cpu().detach().numpy(),'-.', linewidth=0.5, label=f'fit {f}')
#         if i==0: lines.append(a[0]) 
#     a = ax[i].plot(out[0][i].sum(dim=0).cpu().detach().numpy(), 'k--', label='sum')
#     if i==0: lines.append(a[0])


# dset.noise_ = 0
# for i,ind in enumerate(test_inds):
#     a = ax[i].plot(dset[ind][1], label='0-noise')
#     ax[i].set_ylim(0, 20)
#     if i==0: lines.append(a[0])

# ax[0].legend(handles=lines, loc='upper right')

# %%
#

# %%
#

# %%
#

# %%
# # tanh A activation
# import matplotlib.pyplot as plt
# import torch.nn as nn


# plt.clf()
# test_inds= [10,923,2346,3456,5873,7889,8245,9357,9795]
# # batch = next(iter(fitter.dataloader))
# # print(batch[1].shape)

# dset.noise_ = 5
# test_batch = torch.Tensor(dset[test_inds][1]).reshape(-1,1,dset.spec_len).float().to('cuda:0')
# out = fitter.encoder(test_batch.to('cuda:0'))
# # print(out[0].shape)
# px = 0
# fig, ax = plt.subplots(3,3,figsize=(10,10))
# ax=ax.flatten()
# fig.suptitle(f'Random sampler: noise {dset.noise_}, scaling kernel size {dset.scaling_kernel_size}')
# lines = []


# for i,ind in enumerate(test_inds):
#     a = ax[i].plot(test_batch[i].cpu().detach().numpy().flatten(), label='input')
#     if i==0: lines.append(a[0])
#     for f in range(out[0].shape[1]):
#         a = ax[i].plot(out[0][i,f].cpu().detach().numpy(),'-.', linewidth=0.5, label=f'fit {f}')
#         if i==0: lines.append(a[0]) 
#     a = ax[i].plot(out[0][i].sum(dim=0).cpu().detach().numpy(), 'k--', label='sum')
#     if i==0: lines.append(a[0])


# dset.noise_ = 0
# for i,ind in enumerate(test_inds):
#     a = ax[i].plot(dset[ind][1], label='0-noise')
#     ax[i].set_ylim(0, 1)
#     if i==0: lines.append(a[0])

# ax[0].legend(handles=lines, loc='upper right')

# %%
# # A activation
# import matplotlib.pyplot as plt
# plt.clf()
# test_inds= [10,923,2346,3456,5873,7889,8245,9357,9795]
# # batch = next(iter(fitter.dataloader))
# # print(batch[1].shape)

# dset.noise_ = 5
# test_batch = torch.Tensor(dset[test_inds][1]).reshape(-1,1,dset.spec_len).float().to('cuda:0')
# out = fitter.encoder(test_batch.to('cuda:0'))
# # print(out[0].shape)
# px = 0
# fig, ax = plt.subplots(3,3,figsize=(10,10))
# ax=ax.flatten()
# fig.suptitle(f'Random sampler: noise {dset.noise_}, scaling kernel size {dset.scaling_kernel_size}')
# lines = []


# for i,ind in enumerate(test_inds):
#     a = ax[i].plot(test_batch[i].cpu().detach().numpy().flatten(), label='input')
#     if i==0: lines.append(a[0])
#     for f in range(out[0].shape[1]):
#         a = ax[i].plot(out[0][i,f].cpu().detach().numpy(),'-.', linewidth=0.5, label=f'fit {f}')
#         if i==0: lines.append(a[0]) 
#     a = ax[i].plot(out[0][i].sum(dim=0).cpu().detach().numpy(), 'k--', label='sum')
#     if i==0: lines.append(a[0])


# dset.noise_ = 0
# for i,ind in enumerate(test_inds):
#     a = ax[i].plot(dset[ind][1], label='0-noise')
#     ax[i].set_ylim(0, 1)
#     if i==0: lines.append(a[0])

# ax[0].legend(handles=lines, loc='upper right')

# %%
#

# %%
# dset.noise_ = 0
# plt.plot(dset[batch[0][px]][1][px], label='0-noise')

# %% [markdown]
# ## Train

# %%
# from Gaussian_Sampler.models.pv_fitter import Fitter_AE, pseudovoigt_1D_fitters_new
# from autophyslearn.spectroscopic.nn import block_factory, Conv_Block, FC_Block
# from autophyslearn.spectroscopic.nn import Multiscale1DFitter


# num_fits = 4 # number of curves to sum up
# num_params = 4 # number of parameters to fit

# fitter = Fitter_AE(function=pseudovoigt_1D_fitters_new,
#                    dset=dset,
#                    num_params=num_params,
#                    num_fits=num_fits,
#                    input_channels = 1,
#                    learning_rate=3e-3,
#                    device='cuda:0',
#                    encoder = Multiscale1DFitter,
#                    encoder_params = {
#                        "model_block_dict": { # factory wrapper for blocks
#                             "hidden_x1": block_factory(Conv_Block)(output_channels_list=[8,4], 
#                                                                     kernel_size_list=[5,3], 
#                                                                     pool_list=[128], 
#                                                                     max_pool=False),
#                             "hidden_xfc": block_factory(FC_Block)(output_size_list=[64,32]),
#                             "hidden_x2": block_factory(Conv_Block)(output_channels_list=[4,4,4], 
#                                                                     kernel_size_list=[3,3,3], 
#                                                                     pool_list=[8,4], 
#                                                                     max_pool=True),
#                             "hidden_embedding": block_factory(FC_Block)(output_size_list=[8,num_params*num_fits], last=True),
#                         },
#                         # TEST: LIMITS,
#                         "skip_connections": {'hidden_xfc': 'hidden_embedding'},
#                         "function_kwargs": {'limits': [20,dset.shape[-1],dset.shape[-1]] }
#                     },
#                     checkpoint_folder='home/m3learning/Northwestern/Northwestern_link/Gaussian_Sampler/checkpoints',
#                     # sampler = sampler,
#                     # sampler_params = {'dset': dset, 
#                     #                   'batch_size': 100, 
#                     #                   'gaussian_std': 5, 
#                     #                   'orig_shape': dset.shape[0:-1], 
#                     #                   'num_neighbors': 20, },
#                 )

# %% [markdown]
# ### random sampling

# %%
from Gaussian_Sampler.models.pv_fitter import Fitter_AE, pseudovoigt_1D_fitters_new
from autophyslearn.spectroscopic.nn import block_factory, Conv_Block, FC_Block
from autophyslearn.spectroscopic.nn import Multiscale1DFitter
# import wandb
# wandb.login()

# Training unscaled data
num_fits = 8 # number of curves to sum up
num_params = 4 # number of parameters to fit
kernel_sizes = [3,5]
for kernel_size in kernel_sizes:    
    for n,noise in enumerate(dset.noise_levels):
        print('\n', noise)
        dset.noise_ = n
        dset.scaling_kernel_size = kernel_size
    
        fitter = Fitter_AE(function=pseudovoigt_1D_fitters_new,
                        dset=dset,
                        num_params=num_params,
                        num_fits=num_fits,
                        input_channels = 1,
                        device='cuda:0',
                        encoder = Multiscale1DFitter,
                        encoder_params = {
                            "model_block_dict": { # factory wrapper for blocks
                                    "hidden_x1": block_factory(Conv_Block)(output_channels_list=[8,4], 
                                                                            kernel_size_list=[5,3], 
                                                                            pool_list=[256], 
                                                                            max_pool=False),
                                    "hidden_xfc": block_factory(FC_Block)(output_size_list=[128,48]),
                                    "hidden_x2": block_factory(Conv_Block)(output_channels_list=[4,4,4], 
                                                                            kernel_size_list=[3,3,3], 
                                                                            pool_list=[8,4], 
                                                                            max_pool=True),
                                    "hidden_embedding": block_factory(FC_Block)(output_size_list=[8*num_params*num_fits,num_params*num_fits], last=True),
                                },
                                # TEST: LIMITS,
                                "skip_connections": {'hidden_xfc': 'hidden_embedding'},
                                "function_kwargs": {'limits': [1,dset.shape[-1],dset.shape[-1]] }
                            },
                            # sampler = sampler,
                            # sampler_params = {'dset': dset, 
                            #                 'batch_size': 100, 
                            #                 'gaussian_std': 5, 
                            #                 'orig_shape': dset.shape[0:-1], 
                            #                 'num_neighbors': 20, },
                            checkpoint_folder=f'/home/m3learning/Northwestern/Northwestern_link/Gaussian_Sampler/random_sampling/checkpoints_standard_minmax_scaled_{kernel_size}/{noise}/',
                        )
        fitter.train(epochs=101,save_every=10)

# %%
from Gaussian_Sampler.models.pv_fitter import Fitter_AE, pseudovoigt_1D_fitters_new
from autophyslearn.spectroscopic.nn import block_factory, Conv_Block, FC_Block
from autophyslearn.spectroscopic.nn import Multiscale1DFitter
from Gaussian_Sampler.data.custom_sampler import Gaussian_Sampler

# # Training unscaled data
num_fits = 8 # number of curves to sum up
num_params = 4 # number of parameters to fit
kernel_sizes = [3,5]
    
fitter = Fitter_AE(function=pseudovoigt_1D_fitters_new,
                dset=dset,
                num_params=num_params,
                num_fits=num_fits,
                input_channels = 1,
                device='cuda:0',
                encoder = Multiscale1DFitter,
                encoder_params = {
                    "model_block_dict": { # factory wrapper for blocks
                            "hidden_x1": block_factory(Conv_Block)(output_channels_list=[8,4], 
                                                                    kernel_size_list=[5,3], 
                                                                    pool_list=[256], 
                                                                    max_pool=False),
                            "hidden_xfc": block_factory(FC_Block)(output_size_list=[128,48]),
                            "hidden_x2": block_factory(Conv_Block)(output_channels_list=[4,4,4], 
                                                                    kernel_size_list=[3,3,3], 
                                                                    pool_list=[8,4], 
                                                                    max_pool=True),
                            "hidden_embedding": block_factory(FC_Block)(output_size_list=[8*num_params*num_fits,num_params*num_fits], last=True),
                        },
                        # TEST: LIMITS,
                        "skip_connections": {'hidden_xfc': 'hidden_embedding'},
                        "function_kwargs": {'limits': [1,dset.shape[-1],dset.shape[-1]] }
                    },
                )

import matplotlib.pyplot as plt
test_inds= [10,923,2346,3456,5873,7889,8245,9357,9795]

for kernel_size in kernel_sizes:    
    for n,noise in enumerate(dset.noise_levels):
        print('\n', noise)
        dset.noise_ = n
        dset.scaling_kernel_size = kernel_size
        if n==0: zero_noise = dset[:][1]
        
        files = glob.glob(f'/home/m3learning/Northwestern/Northwestern_link/Gaussian_Sampler/random_sampling/checkpoints_standard_minmax_scaled_{kernel_size}/{noise}/*.pkl')
        if len(files)==0:
            print(f'no training for noise {noise} and kernel size {kernel_size}')
            continue
        files.sort()
        checkpoint_path = files[-1]
        fitter.load_weights(checkpoint_path)
        
        plt.clf()

        test_batch = torch.Tensor(dset[test_inds][1]).reshape(-1,1,dset.spec_len).float().to('cuda:0')
        out = fitter.encoder(test_batch.to('cuda:0'))
        # print(out[0].shape)
        px = 0
        fig, ax = plt.subplots(3,3,figsize=(10,10))
        ax=ax.flatten()
        fig.suptitle(f'Random sampler: noise {dset.noise_}, scaling kernel size {dset.scaling_kernel_size}')
        lines = []


        for i,ind in enumerate(test_inds):
            a = ax[i].plot(test_batch[i].cpu().detach().numpy().flatten(), label='input')
            if i==0: lines.append(a[0])
            for f in range(out[0].shape[1]):
                a = ax[i].plot(out[0][i,f].cpu().detach().numpy(),'-.', linewidth=0.5, label=f'fit {f}')
                if i==0: lines.append(a[0]) 
            a = ax[i].plot(out[0][i].sum(dim=0).cpu().detach().numpy(), 'k--', label='sum')
            if i==0: lines.append(a[0])


        for i,ind in enumerate(test_inds):
            a = ax[i].plot(dset.getitem_zero_dset(ind)[1], label='0-noise')
            ax[i].set_ylim(0, 1)
            if i==0: lines.append(a[0])

        ax[0].legend(handles=lines, loc='upper right')
        plt.savefig(f'/home/m3learning/Northwestern/Northwestern_link/Gaussian_Sampler/random_sampling/training_plots/noise_{noise}_kernel_{kernel_size}.png')

# %%
dset.getitem_zero_dset(1)[1].shape

# %% [markdown]
# ### gaussian sampling

# %%
# from Gaussian_Sampler.models.pv_fitter import Fitter_AE, pseudovoigt_1D_fitters_new
# from autophyslearn.spectroscopic.nn import block_factory, Conv_Block, FC_Block
# from autophyslearn.spectroscopic.nn import Multiscale1DFitter
# # import wandb
# # wandb.login()

# # Training unscaled data
# num_fits = 8 # number of curves to sum up
# num_params = 4 # number of parameters to fit
# kernel_sizes = [3,5]
# for kernel_size in kernel_sizes:    
#     for n,noise in enumerate(dset.noise_levels):
#         print('\n', noise)
#         dset.noise_ = n
#         dset.scaling_kernel_size_ = kernel_size
    
#         fitter = Fitter_AE(function=pseudovoigt_1D_fitters_new,
#                         dset=dset,
#                         num_params=num_params,
#                         num_fits=num_fits,
#                         input_channels = 1,
#                         device='cuda:0',
#                         encoder = Multiscale1DFitter,
#                         encoder_params = {
#                             "model_block_dict": { # factory wrapper for blocks
#                                     "hidden_x1": block_factory(Conv_Block)(output_channels_list=[8,4], 
#                                                                             kernel_size_list=[5,3], 
#                                                                             pool_list=[256], 
#                                                                             max_pool=False),
#                                     "hidden_xfc": block_factory(FC_Block)(output_size_list=[128,48]),
#                                     "hidden_x2": block_factory(Conv_Block)(output_channels_list=[4,4,4], 
#                                                                             kernel_size_list=[3,3,3], 
#                                                                             pool_list=[8,4], 
#                                                                             max_pool=True),
#                                     "hidden_embedding": block_factory(FC_Block)(output_size_list=[8*num_params*num_fits,num_params*num_fits], last=True),
#                                 },
#                                 # TEST: LIMITS,
#                                 "skip_connections": {'hidden_xfc': 'hidden_embedding'},
#                                 "function_kwargs": {'limits': [1,dset.shape[-1],dset.shape[-1]] }
#                             },
#                             sampler = Gaussian_Sampler,
#                             sampler_params = {'dset': dset, 
#                                             'batch_size': 100, 
#                                             'gaussian_std': 5, 
#                                             'orig_shape': dset.shape[0:-1], 
#                                             'num_neighbors': 20, },
#                             checkpoint_folder=f'/home/m3learning/Northwestern/Northwestern_link/Gaussian_Sampler/gaussian_sampling/checkpoints_standard_minmax_scaled_{kernel_size}/{noise}/',
#                         )
#         fitter.train(epochs=101,save_every=10)

# %%
from Gaussian_Sampler.models.pv_fitter import Fitter_AE, pseudovoigt_1D_fitters_new
from autophyslearn.spectroscopic.nn import block_factory, Conv_Block, FC_Block
from autophyslearn.spectroscopic.nn import Multiscale1DFitter
from Gaussian_Sampler.data.custom_sampler import Gaussian_Sampler

# # Training unscaled data
num_fits = 8 # number of curves to sum up
num_params = 4 # number of parameters to fit
kernel_sizes = [1,3,5]
    
fitter = Fitter_AE(function=pseudovoigt_1D_fitters_new,
                dset=dset,
                num_params=num_params,
                num_fits=num_fits,
                input_channels = 1,
                device='cuda:0',
                encoder = Multiscale1DFitter,
                encoder_params = {
                    "model_block_dict": { # factory wrapper for blocks
                            "hidden_x1": block_factory(Conv_Block)(output_channels_list=[8,4], 
                                                                    kernel_size_list=[5,3], 
                                                                    pool_list=[256], 
                                                                    max_pool=False),
                            "hidden_xfc": block_factory(FC_Block)(output_size_list=[128,48]),
                            "hidden_x2": block_factory(Conv_Block)(output_channels_list=[4,4,4], 
                                                                    kernel_size_list=[3,3,3], 
                                                                    pool_list=[8,4], 
                                                                    max_pool=True),
                            "hidden_embedding": block_factory(FC_Block)(output_size_list=[8*num_params*num_fits,num_params*num_fits], last=True),
                        },
                        # TEST: LIMITS,
                        "skip_connections": {'hidden_xfc': 'hidden_embedding'},
                        "function_kwargs": {'limits': [1,dset.shape[-1],dset.shape[-1]] }
                    },
                    sampler = Gaussian_Sampler,
                    sampler_params = {'dset': dset, 
                                    'batch_size': 100, 
                                    'gaussian_std': 5, 
                                    'orig_shape': dset.shape[0:-1], 
                                    'num_neighbors': 20, },
                    checkpoint_folder=f'/home/m3learning/Northwestern/Northwestern_link/Gaussian_Sampler/gaussian_sampling/checkpoints_standard_minmax_scaled_{kernel_size}/{noise}/',
                )

import matplotlib.pyplot as plt
test_inds= [10,923,2346,3456,5873,7889,8245,9357,9795]

for kernel_size in kernel_sizes:    
    for n,noise in enumerate(dset.noise_levels):
        print('\n', noise)
        dset.noise_ = n
        dset.scaling_kernel_size = kernel_size
        
        if n==0: zero_noise = dset[:][1]
        
        files = glob.glob(f'/home/m3learning/Northwestern/Northwestern_link/Gaussian_Sampler/gaussian_sampling/checkpoints_standard_minmax_scaled_{kernel_size}/{noise}/*.pkl')
        files.sort()
        checkpoint_path = files[-1]
        fitter.load_weights(checkpoint_path)
        
        plt.clf()

        test_batch = torch.Tensor(dset[test_inds][1]).reshape(-1,1,dset.spec_len).float().to('cuda:0')
        out = fitter.encoder(test_batch.to('cuda:0'))
        # print(out[0].shape)
        px = 0
        fig, ax = plt.subplots(3,3,figsize=(10,10))
        ax=ax.flatten()
        fig.suptitle(f'Gaussian sampler: noise {dset.noise_}, scaling kernel size {dset.scaling_kernel_size}')
        lines = []


        for i,ind in enumerate(test_inds):
            a = ax[i].plot(test_batch[i].cpu().detach().numpy().flatten(), label='input')
            if i==0: lines.append(a[0])
            for f in range(out[0].shape[1]):
                a = ax[i].plot(out[0][i,f].cpu().detach().numpy(),'-.', linewidth=0.5, label=f'fit {f}')
                if i==0: lines.append(a[0]) 
            a = ax[i].plot(out[0][i].sum(dim=0).cpu().detach().numpy(), 'k--', label='sum')
            if i==0: lines.append(a[0])


        for i,ind in enumerate(test_inds):
            a = ax[i].plot(dset.getitem_zero_dset(ind)[1], label='0-noise')
            ax[i].set_ylim(0, 1)
            if i==0: lines.append(a[0])

        ax[0].legend(handles=lines, loc='upper right')
        plt.savefig(f'/home/m3learning/Northwestern/Northwestern_link/Gaussian_Sampler/gaussian_sampling/training_plots/noise_{noise}_kernel_{kernel_size}.png')

# %% [markdown]
# ### make comparison visualization

# %%
gaussian_sampling = glob.glob('/home/m3learning/Northwestern/Northwestern_link/Gaussian_Sampler/gaussian_sampling/training_plots/*')
gaussian_sampling.sort()
gaussian_sampling = [gaussian_sampling[i::3] for i in range(3)]

random_sampling = glob.glob('/home/m3learning/Northwestern/Northwestern_link/Gaussian_Sampler/random_sampling/training_plots/*')
random_sampling.sort()
random_sampling = [random_sampling[i::3] for i in range(3)]

# %%
import panel as pn
import holoviews as hv
import holoviews.streams as streams


def display_panels(scaling_kernel, noise):
    g_img = gaussian_sampling[scaling_kernel][noise]
    r_img = random_sampling[scaling_kernel][noise]
    g_panel = pn.pane.PNG(g_img, width=700)
    r_panel = pn.pane.PNG(r_img, width=700)
    return pn.Row(g_panel, r_panel)

k_slider = pn.widgets.IntSlider(name='Kernel', value=0, start=0, end=len(gaussian_sampling)-1)
n_slider = pn.widgets.IntSlider(name='Noise', value=0, start=0, end=len(gaussian_sampling[0])-1)

# Use pn.bind for reactive linking
viewer = pn.bind(display_panels, scaling_kernel=k_slider, noise=n_slider)

layout = pn.Column(
    pn.Row(k_slider, n_slider),
    viewer
)

layout.show(port=5007, websocket_origin="*",threaded=True)  # Required for `panel serve`

# %%
import glob

files = glob.glob(f'/home/m3learning/Northwestern/Northwestern_link/Gaussian_Sampler/gaussian_sampling/*/*/*.pkl')
files = [f for f in files if not '2025-04-22' in f]
files.sort()

# %%
import os

for file in files:
    os.remove(file)

# %% [markdown]
# ## Fetch embeddings for all noise levels

# %%
# from Gaussian_Sampler.data.datasets import Fake_PV_Embeddings
# emb = Fake_PV_Embeddings(dset, fitter, fitter.checkpoint_folder)

# %%
# import glob
# from Gaussian_Sampler.data.datasets import Fake_PV_Embeddings
# kernel_sizes = [1,3,5,7,9]
# for kernel_size in kernel_sizes:    
#     for n,noise in enumerate(dset.noise_levels):
#         print('\n', noise)
#         dset.noise_ = n
#         checkpoint_path = glob.glob(f'/home/m3learning/Northwestern/Northwestern_link/Gaussian_Sampler/checkpoints_standard_minmax_scaled_{kernel_size}/{noise}/*.pkl')
#         checkpoint_path.sort()
#         checkpoint_path = checkpoint_path[-1]
#         fitter.load_weights(checkpoint_path)
        
#         emb = Fake_PV_Embeddings(dset, fitter, checkpoint_path)
#         emb.write_embeddings(overwrite=True)

# %% [markdown]
# ## Visualize embeddings

# %% [markdown]
# ### quick

# %%
kernel_size = 1
checks = glob.glob(f'/home/m3learning/Northwestern/Northwestern_link/Gaussian_Sampler/random_sampling/checkpoints_standard_minmax_scaled_{kernel_size}/*/*100*.pkl')
# checks = glob.glob(f'/home/m3learning/Northwestern/Northwestern_link/Gaussian_Sampler/checkpoints_standard_minmax_scaled/*/*100*.pkl')
checks.sort()
checkpoint_path = checks[10]
fitter.load_weights(checkpoint_path)

# %%
fitter.checkpoint_folder

# %%
import test_disp
test_disp.plot_batch(fitter, dset)

# %% [markdown]
# ### all

# %%
# from Gaussian_Sampler.data.datasets import Fake_PV_Embeddings
# from Gaussian_Sampler.viz.hv_viz import Fake_PV_viz_embeddings
# kernel_size = 5
# checks = glob.glob(f'/home/m3learning/Northwestern/Northwestern_link/Gaussian_Sampler/random_sampling/checkpoints_standard_minmax_scaled_{kernel_size}/*/*100*.pkl')
# # checks = glob.glob(f'/home/m3learning/Northwestern/Northwestern_link/Gaussian_Sampler/checkpoints_standard_minmax_scaled/*/*100*.pkl')
# checks.sort()
# checkpoint_path = checks[4]
# fitter.load_weights(checkpoint_path)

# emb = Fake_PV_Embeddings(dset, fitter, checkpoint_path)
# emb.write_embeddings(overwrite=False)

# %%
# # fitter._dataloader_sampler = sampler
# emb_viz = Fake_PV_viz_embeddings(fitter, emb, dset)

# %%
# import panel as pn
# pn.extension()
# fits_params = emb_viz.layout_fits_params()
# # pn.serve(fits_params, port=5006)
# res = fits_params.show(port=5006, websocket_origin="*",threaded=True)

# %%
# res.stop()

# %%
# dset.kernel_scalers[0]

# %%
# fits_params.stop()

# %%
# dset.h5_keys().index(emb._noise)

# %%
# emb_viz.select_fits_params(which=0).shape

# %% [markdown]
# <!--  -->

# %%
#

# %% [markdown]
# <!--  -->

# %%
# import os
# def load_weights(self, path_checkpoint):
#     """loads the weights from a checkpoint

#     Args:
#         path_checkpoint (str): path where checkpoints are saved 
#     """
#     print(f"Attempting to load checkpoint from: {path_checkpoint}")
    
#     # Debug: Let's look at the first few bytes of the file
#     with open(path_checkpoint, 'rb') as f:
#         first_bytes = f.read(20)
#         print(f"First bytes of file: {first_bytes}")
        
#     self.checkpoint = path_checkpoint
#     checkpoint = torch.load(path_checkpoint, weights_only=False)
#     self.encoder.load_state_dict(checkpoint['encoder'])
#     self.optimizer.load_state_dict(checkpoint['optimizer'])

# %%
# load_weights(fitter, checkpoint_path)

# %%
# class fake_pv_FitterAutoencoder_1D(stem.FitterAutoencoder_1D):
#     def __init__(self, *args, **kwargs):
#         super().__init__(*args, **kwargs)

#     def compile_model(self):
#         """function that complies the neural network model
#         """
#         self.Fitter = stem.Multiscale1DFitter(function=self.function,
#                                  x_data = self.dset,
#                                  input_channels=self.dset.shape[1],
#                                  num_params=self.num_params,
#                                  num_fits=self.num_fits,
#                                  limits=self.limits,
#                                  device='cuda:0',
#                                  flatten_from = 1,
#                             )
#         self.Fitter = self.Fitter.to(self.device)
#         # sets the datatype of the model to float32
#         self.Fitter.type(torch.float32)

#         # sets the optimizers
#         self.optimizer = torch.optim.Adam(
#             self.Fitter.parameters(), lr=self.learning_rate
#         )
        
#     def get_embedding(self, data, batch_size=32,train=True,check=None):
#         """extracts embeddings from the data

#         Args:
#             data (torch.tensor): data to get embeddings from
#             batch_size (int, optional): batchsize for inference. Defaults to 32.

#         Returns:
#             torch.tensor: predicted embeddings
#         """

#         # builds the dataloader
#         dataloader = DataLoader(data, batch_size, shuffle=False)
#         s = data.shape
#         try:
#             try: h = h5py.File(f'{self.folder}/{self.emb_h5}','w')
#             except: h = h5py.File(f'{self.folder}/{self.emb_h5}','r+')

#             try: check = self.checkpoint.split('/')[-1][:-4]
#             except: check=check
            
#             # make embedding dataset
#             try:
#                 embedding_ = h.create_dataset(f'embedding_{check}', 
#                                             #   data = np.zeros([s[0], s[1], self.num_fits, self.num_params]),
#                                               shape=(s[0], s[1], self.num_fits, self.num_params),
#                                               dtype='float32')  
#             except: 
#                 embedding_ = h[f'embedding_{check}']
                
#             # make fitted dataset
#             try:
#                 fits_ = h.create_dataset(f'fits_{check}', 
#                                         #  data = np.zeros([s[0],self.num_fits,s[1],s[2]]),
#                                          shape = (s[0],s[1],self.num_fits,s[2]),
#                                          dtype='float32')  
#             except:
#                 fits_ = h[f'fits_{check}']

#             self.embedding = embedding_
#             self.fits = fits_

#         except Exception as error:
#             print(error) 
#             assert train,"No h5_dataset embedding dataset created"
#             print('Warning: not saving to h5')
                
#         if train: 
#             print('Created empty h5 embedding datasets to fill during training')
#             return 1 # do not calculate. 
#             # return true to indicate this is filled during training

#         else:
#             s=embedding_.shape
#             for i, (inds,x) in enumerate(tqdm(dataloader, leave=True, total=len(dataloader))):
#                 with torch.no_grad():
#                     value = x
#                     batch_size = x.shape[0]
#                     test_value = Variable(value.to(self.device))
#                     test_value = test_value.float()
#                     embedding,fit = self.Fitter(test_value,return_sum=False)
                    
#                     self.embedding[i*batch_size:(i+1)*batch_size] = embedding.reshape(batch_size,s[1],s[2],s[3]).cpu().detach().numpy()
#                     self.fits[i*batch_size:(i+1)*batch_size] = data.unscale(fit,inds).reshape(batch_size,s[1],self.num_fits,-1).cpu().detach().numpy()
                   
#         h.close()

# %%
# a = torch.Tensor([[1,2,3],[4,5,6]])
# b = torch.Tensor([[4,5,6],[4,5,6]])
# c = torch.Tensor([[],[]])

# torch.cat([a,b,c],dim=1)

# %% [markdown]
# <!-- l = [1,2,3,4,5]
# l.insert[-2,'a']
# l.insert[-1,'b']
# l -->

# %% [markdown]
# <!-- ## gaussian sampler and fitter 1D -->

# %%
# datapath

# %%
# dset.save_folder

# %%
# dset.h5

# %%
# from Gaussian_Sampler.models.base_model import Averaging_Loss_AE
# emb_path = '/home/m3learning/Northwestern/Northwestern_link/model_tests/fake_pv_curves_gaussian_sampling/'

# for dset_key in dset.h5_keys():
#     dset.noise_ = dset_key
#     model = Averaging_Loss_AE(function=stem.generate_pseudovoigt_1D,
#                                         dset = dset,
#                                         input_channels=1,
#                                         num_params=4,
#                                         num_fits=1,
#                                         limits=[1000, 500, 500], # A, mean, fwhm 
#                                         device='cuda:0',
#                                         learning_rate = 3e-5,
#                                         folder=f'{emb_path}/profiling/{dset_key}',
#                                         # wandb_project='fit_noisy_pv_gaussian_batch_sampling_',
#                                         dataloader_sampler = Gaussian_Sampler,
#                                         sampler_kwargs = {'dset': dset, 
#                                                         'batch_size': 100,
#                                                         'gaussian_std': 2,
#                                                         'original_shape': (100,100,500),
#                                                         'num_neighbors': 10,},
#                                         custom_collate_fn=custom_collate_fn,
#                                     )    
#     model.Train(dset, 
#                 epochs=50, 
#                 # batch_size=101, 
#                 save_model_every=10,#minibatch_logging_rate=99,
#                 with_scheduler=False,
#                 wandb_init={'notes':dset_key},
#                 binning=True)

# %% [markdown]
# <!-- ## Random Sampling -->

# %%
# emb_path = '/home/m3learning/Northwestern/Northwestern_link/model_tests/fake_pv_curves_random_sampling/'

# %% [markdown]
# <!-- ### spectral noise -->

# %%
# raw_data_path = f'{datapath}fake_pv_uniform_spectral_noise.h5'
# emb_path = '/home/m3learning/Northwestern/Northwestern_link/model_tests/fake_pv_curves_random_sampling/'

# for dset_name in dset_list:
#     print(dset_name)
#     with h5py.File(raw_data_path,'r') as f:
#         dataset = Indexing_Dataset( f[dset_name][:].reshape(-1,1,500) )
        
#     model = fake_pv_FitterAutoencoder_1D(function=stem.generate_pseudovoigt_1D,
#                                         dset = dataset,
#                                         input_channels=1,
#                                         num_params=4,
#                                         num_fits=1,
#                                         limits=[1000, 500, 500], # A, mean, fwhm 
#                                         device='cuda:0',
#                                         learning_rate = 3e-3,
#                                         folder=f'{emb_path}/spectral_noise/{dset_name}',
#                                         # wandb_project='fit_noisy_pv_gaussian_batch_sampling_',
#                                     )    
#     model.Train(dataset, epochs=50, batch_size=101, save_model_every=10,#minibatch_logging_rate=99,
#                 with_scheduler=False,wandb_init={'notes':dset_name},binning=False)

# %% [markdown]
# <!-- ## scipy -->

# %%
# from scipy.optimize import curve_fit
# import os

# emb_path = '/home/m3learning/Northwestern/Northwestern_link/model_tests/fake_pv_curves_scipy/'
# os.makedirs(emb_path, exist_ok=True)

# %%
with h5py.File('/home/m3learning/Northwestern/Northwestern_link/model_tests/fake_pv_curves_gaussian_sampling/pv_scipy_fits.h5', 'a') as f:
    print(f.keys())

# %% [markdown]
# <!-- #### spectral noise -->

# %%
# raw_data_path = f'{datapath}fake_pv_uniform_spectral_noise.h5'
# def pv_fit(x_data,A,x,w,nu):
#     return write_pseudovoight(A,x,w,nu,spec_len=len(x_data))

# # Set parameter bounds
# param_bounds = (
#     [0, 0, 0, 0],       # Lower bounds for A, x0, w, nu
#     [np.inf, 500, 500, 1]  # Upper bounds for A, x0, w, nu
# )

# initial_guesses = [1,250,25,0.2] # A, x, w, nu

# with h5py.File(raw_data_path,'a') as f:
#     keys = list(f.keys())
#     for ind,key in enumerate(tqdm(keys)):
#         if ind<10: continue
#         y_data = f[key][:]
#         with h5py.File(f'{emb_path}pv_scipy_spectral_noise_fits.h5','a') as h:
#             try: emb = h[f'emb_{key}']
#             except: emb = h.create_dataset(f'emb_{key}', shape=(y_data.shape[0],y_data.shape[1],4), dtype=np.float32)
        
#             try: fit = h[f'fit_{key}']
#             except: fit = h.create_dataset(f'fit_{key}', shape=(y_data.shape[0],y_data.shape[1],y_data.shape[2]), dtype=np.float32)
        
#             for x_ in range(y_data.shape[0]):
#                 for y_ in range(y_data.shape[1]):
#                     try:
#                         # Fit the data
#                         popt, pcov = curve_fit(
#                             pv_fit,
#                             np.linspace(0,499,500),
#                             y_data[x_,y_],
#                             p0=initial_guesses,
#                             bounds=param_bounds,
#                         )
#                         emb[x_,y_] = popt
#                         fit[x_,y_] = pv_fit(np.linspace(0,499,500),*popt)
#                     except: pass

# %% [markdown]
# <!-- #### image noise -->

# %%
# raw_data_path = f'{datapath}fake_pv_uniform_image_noise.h5'

# def pv_fit(x_data,A,x,w,nu):
#     return write_pseudovoight(A,x,w,nu,spec_len=len(x_data))

# # Set parameter bounds
# param_bounds = (
#     [0, 0, 0, 0],       # Lower bounds for A, x0, w, nu
#     [np.inf, 500, 500, 1]  # Upper bounds for A, x0, w, nu
# )

# initial_guesses = [1,250,25,0.2] # A, x, w, nu

# with h5py.File(raw_data_path,'a') as f:
#     keys = list(f.keys())
#     for ind,key in enumerate(tqdm(keys)):
#         y_data = f[key][:]
#         with h5py.File(f'{emb_path}pv_scipy_image_noise_fits.h5','a') as h:
#             try: emb = h[f'emb_{key}']
#             except: emb = h.create_dataset(f'emb_{key}', shape=(y_data.shape[0],y_data.shape[1],4), dtype=np.float32)
        
#             try: fit = h[f'fit_{key}']
#             except: fit = h.create_dataset(f'fit_{key}', shape=(y_data.shape[0],y_data.shape[1],y_data.shape[2]), dtype=np.float32)
        
#             for x_ in range(y_data.shape[0]):
#                 for y_ in range(y_data.shape[1]):
#                     try:
#                         # Fit the data
#                         popt, pcov = curve_fit(
#                             pv_fit,
#                             np.linspace(0,499,500),
#                             y_data[x_,y_],
#                             p0=initial_guesses,
#                             bounds=param_bounds,
#                         )
#                         emb[x_,y_] = popt
#                         fit[x_,y_] = pv_fit(np.linspace(0,499,500),*popt)
#                     except: pass

# %% [markdown]
# <!-- ## Get embeddings -->

# %% [markdown]
# <!-- ### gaussian -->

# %% [markdown]
# <!-- #### spectral -->

# %%
# emb_path = '/home/m3learning/Northwestern/Northwestern_link/model_tests/fake_pv_curves_gaussian_sampling/'

# noise = 'spectral_noise'
# raw_data_path = f'{datapath}fake_pv_uniform_{noise}.h5'

# model = fake_pv_FitterAutoencoder_1D(function=stem.generate_pseudovoigt_1D,
#                                     dset = dataset,
#                                     input_channels=1,
#                                     num_params=4,
#                                     num_fits=1,
#                                     limits=[1000, 500, 500], # A, mean, fwhm 
#                                     device='cuda:0',
#                                     learning_rate = 3e-5,
#                                     # wandb_project='fit_noisy_pv_gaussian_batch_sampling',
#                                     dataloader_sampler = Gaussian_Sampler,
#                                     sampler_kwargs = {'dset': dataset, 
#                                                     'batch_size': 100,
#                                                     'gaussian_std': 5,
#                                                     'original_shape': (100,100,500),
#                                                     'num_neighbors': 20,},
#                                     custom_collate_fn=custom_collate_fn,
#                                     )                             
# for dset_name in dset_list:
#     print(dset_name)
#     with h5py.File(raw_data_path,'r') as f:
#         dataset = Indexing_Dataset( f[dset_name][:].reshape(-1,1,500), zero_dset=f['00.000_noise'][:].reshape(-1,1,500) ) 
#         checks = glob.glob(f'{emb_path}/{noise}/{dset_name}/*.pkl')
#         checks.sort()
#         model.load_weights(checks[-1])
#         model.get_embedding(dataset, batch_size=100, train=False)

# %% [markdown]
# <!-- #### image -->

# %%
# emb_path = '/home/m3learning/Northwestern/Northwestern_link/model_tests/fake_pv_curves_gaussian_sampling/'
# noise = 'image_noise'
# raw_data_path = f'{datapath}fake_pv_uniform_{noise}.h5'

# model = fake_pv_FitterAutoencoder_1D(function=stem.generate_pseudovoigt_1D,
#                                     dset = dataset,
#                                     input_channels=1,
#                                     num_params=4,
#                                     num_fits=1,
#                                     limits=[1000, 500, 500], # A, mean, fwhm 
#                                     device='cuda:0',
#                                     learning_rate = 3e-5,
#                                     # wandb_project='fit_noisy_pv_gaussian_batch_sampling',
#                                     dataloader_sampler = Gaussian_Sampler,
#                                     sampler_kwargs = {'dset': dataset, 
#                                                     'batch_size': 100,
#                                                     'gaussian_std': 5,
#                                                     'original_shape': (100,100,500),
#                                                     'num_neighbors': 20,},
#                                     custom_collate_fn=custom_collate_fn,
#                                     )                           

# for dset_name in dset_list:
#     print(dset_name)
#     with h5py.File(raw_data_path,'r') as f:
#         dataset = Indexing_Dataset( f[dset_name][:].reshape(-1,1,500), zero_dset=f['00.000_noise'][:].reshape(-1,1,500) ) 
#         checks = glob.glob(f'{emb_path}/{noise}/{dset_name}/*.pkl')
#         checks.sort()
#         model.load_weights(checks[-1])
#         model.get_embedding(dataset, batch_size=100, train=False)

# %% [markdown]
# <!-- ### random -->

# %% [markdown]
# <!-- #### image -->

# %%
# emb_path = '/home/m3learning/Northwestern/Northwestern_link/model_tests/fake_pv_curves_random_sampling/'
# noise = 'image_noise'
# raw_data_path = f'{datapath}fake_pv_uniform_{noise}.h5'

# model = fake_pv_FitterAutoencoder_1D(function=stem.generate_pseudovoigt_1D,
#                                     dset = dataset,
#                                     input_channels=1,
#                                     num_params=4,
#                                     num_fits=1,
#                                     limits=[1000, 500, 500], # A, mean, fwhm 
#                                     device='cuda:0',
#                                     learning_rate = 3e-5,
#                                     # wandb_project='fit_noisy_pv_gaussian_batch_sampling',
#                                     dataloader_sampler = Gaussian_Sampler,
#                                     sampler_kwargs = {'dset': dataset, 
#                                                     'batch_size': 100,
#                                                     'gaussian_std': 5,
#                                                     'original_shape': (100,100,500),
#                                                     'num_neighbors': 20,},
#                                     custom_collate_fn=custom_collate_fn,
#                                     )  

# for dset_name in dset_list:
#     print(dset_name)
#     with h5py.File(raw_data_path,'r') as f:
#         dataset = Indexing_Dataset( f[dset_name][:].reshape(-1,1,500), zero_dset=f['00.000_noise'][:].reshape(-1,1,500) ) 
#         checks = glob.glob(f'{emb_path}/{noise}/{dset_name}/*.pkl')
#         checks.sort()
#         model.load_weights(checks[-1])
#         model.get_embedding(dataset, batch_size=100, train=False)

# %% [markdown]
# <!-- #### spectral -->

# %%
# emb_path = '/home/m3learning/Northwestern/Northwestern_link/model_tests/fake_pv_curves_random_sampling/'
# noise = 'spectral_noise'
# raw_data_path = f'{datapath}fake_pv_uniform_{noise}.h5'

# model = fake_pv_FitterAutoencoder_1D(function=stem.generate_pseudovoigt_1D,
#                                     dset = dataset,
#                                     input_channels=1,
#                                     num_params=4,
#                                     num_fits=1,
#                                     limits=[1000, 500, 500], # A, mean, fwhm 
#                                     device='cuda:0',
#                                     learning_rate = 3e-5,
#                                     # wandb_project='fit_noisy_pv_gaussian_batch_sampling',
#                                     dataloader_sampler = Gaussian_Sampler,
#                                     sampler_kwargs = {'dset': dataset, 
#                                                     'batch_size': 100,
#                                                     'gaussian_std': 5,
#                                                     'original_shape': (100,100,500),
#                                                     'num_neighbors': 20,},
#                                     custom_collate_fn=custom_collate_fn,
#                                     )  

# for dset_name in dset_list:
#     print(dset_name)
#     with h5py.File(raw_data_path,'r') as f:
#         dataset = Indexing_Dataset( f[dset_name][:].reshape(-1,1,500), zero_dset=f['00.000_noise'][:].reshape(-1,1,500) ) 
#         checks = glob.glob(f'{emb_path}/{noise}/{dset_name}/*.pkl')
#         checks.sort()
#         model.load_weights(checks[-1])
#         model.get_embedding(dataset, batch_size=100, train=False)

# %%
# with model.open_embedding_h() as h:
#     print(h.keys())

# %% [markdown]
# <!-- ## VIZ -->

# %%
# # Layout with widgets and plots
# dmap = pn.Column(
#     pn.Row(i_slider, s_slider, noise_selector),
#     pn.Row(x_slider, y_slider, sampler_selector),
#     (img_dmap*dot_dmap + \
#         fit_img_dmap*dot_dmap + \
#         spec_dmap*fit_spec_dmap*zero_spec_dmap*vline_dmap).opts(shared_axes=True,axiswise=True),
#     hv.Layout(embedding_dmaps).cols(4)
# )

# dmap

# %%
# dmap.clear()

# %%
#
