# %% [markdown]
# # Utility/imports

# %%
# %load_ext autoreload
# %autoreload 2

# import os
# os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"  # Ensures consistent ordering of GPU devices
# os.environ["CUDA_VISIBLE_DEVICES"] = "0"  
device_=4
import numpy as np
from tqdm import tqdm
import h5py

import holoviews as hv
import panel as pn

hv.extension('bokeh')
pn.extension('bokeh')

import h5py

import torch
import glob

import sys
sys.path.append('..') # path to the src directory
sys.path.append('/home/m3learning/Northwestern/M3Learning-Util/src')
sys.path.append('/home/m3learning/Northwestern/AutoPhysLearn/src')


import matplotlib.pyplot as plt
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='77f1d73b-99cc-4fae-adf6-5639a07f7471'>
#   <div id="f9c9c829-fb5b-4a9e-9d47-02e8c1cdf687" data-root-id="77f1d73b-99cc-4fae-adf6-5639a07f7471" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"b3050c89-006e-4436-879a-cb8266d7a9c6":{"version":"3.7.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"77f1d73b-99cc-4fae-adf6-5639a07f7471"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"3be9396f-7e82-49a1-9180-6dd2dfcbc13d","attributes":{"plot_id":"77f1d73b-99cc-4fae-adf6-5639a07f7471","comm_id":"97f35bce68974b7b956975dab92e07fb","client_comm_id":"845ebc7a79154373a20b905b3a23c3b1"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1" ...
#   var render_items = [{"docid":"b3050c89-006e-4436-879a-cb8266d7a9c6","roots":{"77f1d73b-99cc-4fae-adf6-5639a07f7471":"f9c9c829-fb5b-4a9e-9d47-02e8c1cdf687"},"root_ids":["77f1d73b-99cc-4fae-adf6-5639a07f7471"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# WARNING:param.panel_extension: bokeh extension not recognized and will be skipped.
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# ## sweep gaussian

# %%
# Import the W&B Python Library and log into W&B
import wandb

wandb.login()

# 2: Define the search space
sweep_configuration = {
    "method": "grid",
    "metric": {"goal": "minimize", "name": "score"},
    "parameters": {
        "scaling_kernel_size": {"values": [1, 3, 5]},
        "gaussian_std": {"values": [1.0, 3.0, 5.0]},
        "num_neighbors": {"values": [4, 8, 12, 20]},
        "num_fits": {"values": [2, 6, 10]},
        "lr": {"values": [1e-5, 5e-5, 1e-4]},  # explicitly list a few log-scale points

        "hidden_x1_depth": {"values": [1, 2, 3, 4]},
        "hidden_xfc_depth": {"values": [1, 2, 3, 4]},
        "hidden_x2_depth": {"values": [1, 2, 3, 4]},
    },
}

hidden_x1_depth_dict = {1: {'output_channels_list':[8,4],
                            'kernel_size_list':[5,3], 
                            'pool_list':[128], }, 
                        2: {'output_channels_list':[8,4,4],
                            'kernel_size_list':[5,3,3], 
                            'pool_list':[128], }, 
                        3: {'output_channels_list':[8,4,4,4],
                            'kernel_size_list':[5,3,3,3], 
                            'pool_list':[128], }, 
                        4: {'output_channels_list':[8,4,4,4,4],
                            'kernel_size_list':[5,3,3,3,3], 
                            'pool_list':[128], } }

hidden_xfc_depth_dict = {1: {'output_size_list':[32]}, 
                         2: {'output_size_list':[64,32]}, 
                         3: {'output_size_list':[128,64,32]},
                         4: {'output_size_list':[128,72,64,32]} }

hidden_x2_depth_dict = {1: lambda fits: {'output_channels_list':[4,4],
                                         'kernel_size_list':[5,3], 
                                         'pool_list':[fits], }, 
                        2: lambda fits: {'output_channels_list':[4,4,4],
                                         'kernel_size_list':[5,3,3], 
                                         'pool_list':[int(fits*1.5), fits], }, 
                        3: lambda fits: {'output_channels_list':[4,4,4,4],
                                         'kernel_size_list':[5,3,3,3], 
                                         'pool_list':[int(fits*1.5), fits, fits], }, 
                        4: lambda fits: {'output_channels_list':[4,4,4,4,4],
                                         'kernel_size_list':[5,3,3,3,3], 
                                         'pool_list':[int(fits*1.5), fits, fits], }}
# Out:
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: zhang-xinqiao to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
from Gaussian_Sampler.data.datasets import Fake_PV_Dataset
from Gaussian_Sampler.models.pv_fitter import pseudovoigt_1D_fitters_new
datapath = f'/home/xz498/Gaussian_Sampler_Data/{device_}/'

fitter = pseudovoigt_1D_fitters_new(limits = [1,1,750])

# # write new dataset if needed
# dset = Fake_PV_Dataset(shape=(100,100,750),
#                        save_folder=datapath,
#                        pv_param_classes={'h':[5,6,9,10,7], 'E':[0,100,400,500,700], 'F':[50,50,70,90,90], 'nu':[0.7,0.7,0.7,0.4,0.4]},
#                        pv_fitter=fitter,
#                        scaled=True, # make sure to change 
#                        noise_level=0, # make sure to change in other places
#                        # TEST: scaling kernel size
#                        scaling_kernel_size=1,
#                        overwrite=True
#                        )

# %%
def initialize_dataset(config,noise):
    return Fake_PV_Dataset(shape=(100,100,750),
                        save_folder=datapath,
                        pv_param_classes={'h':[5,6,9,10,7], 'E':[0,100,400,500,700], 'F':[50,50,70,90,90], 'nu':[0.7,0.7,0.7,0.4,0.4]},
                        pv_fitter=fitter,
                        scaled=True,
                        noise_level=noise,
                        scaling_kernel_size=config.scaling_kernel_size,) #!

# %%
from Gaussian_Sampler.data.custom_sampler import Gaussian_Sampler    
def initialize_sampler(dset, config):
    return Gaussian_Sampler(dset, 
                            batch_size=1000, #!
                            orig_shape=dset.shape[0:-1], 
                            gaussian_std=config.gaussian_std, #!
                            num_neighbors=config.num_neighbors) #!

# %%
from Gaussian_Sampler.models.pv_fitter import Fitter_AE
from autophyslearn.spectroscopic.nn import block_factory, Conv_Block, FC_Block
from autophyslearn.spectroscopic.nn import Multiscale1DFitter
from Gaussian_Sampler.data.custom_sampler import Gaussian_Sampler

def initialize_model(dset, config):
    num_params = 4
    return Fitter_AE(function=pseudovoigt_1D_fitters_new,
                        dset=dset,
                        num_params=num_params,
                        num_fits=config.num_fits,
                        input_channels = 1,
                        learning_rate=config.lr,
                        device=f'cuda:{device_}',
                        encoder = Multiscale1DFitter,
                        encoder_params = {
                            "model_block_dict": { # factory wrapper for blocks
                                    "hidden_x1": block_factory(Conv_Block)(max_pool=False,
                                                                            **hidden_x1_depth_dict[config.hidden_x1_depth]), 
                                    "hidden_xfc": block_factory(FC_Block)(**hidden_xfc_depth_dict[config.hidden_xfc_depth]),
                                    "hidden_x2": block_factory(Conv_Block)(max_pool=False, 
                                                                           **hidden_x2_depth_dict[config.hidden_x2_depth](config.num_fits)),
                                    "hidden_embedding": block_factory(FC_Block)(output_size_list=[8*config.num_fits,num_params*config.num_fits], last=True),
                                },
                                # TEST: LIMITS,
                                "skip_connections": { 'hidden_xfc': 'hidden_embedding' },
                                "function_kwargs": { 'limits': [1,dset.shape[-1],dset.shape[-1]] }
                            },
                            checkpoint_folder=f'{datapath}/checkpoints/wandb_sweep',
                            sampler = Gaussian_Sampler,
                            sampler_params = {  'dset': dset, 
                                                'batch_size': 2000, 
                                                'gaussian_std': config.gaussian_std, 
                                                'orig_shape': dset.shape[0:-1], 
                                                'num_neighbors': config.num_neighbors, }, 
                            )

# %%
def is_valid_config(config):
    # Skip if large neighbors with small std
    if config.num_neighbors > 10 and config.gaussian_std < 3.0:
        return False
    return True

def train_model(config,noise):
    dset = initialize_dataset(config,noise)
    # sampler = initialize_sampler(dset, config)
    model = initialize_model(dset, config)
    print(model.encoder.hidden_x1.hidden[0].weight.device)
    # print(list(model.encoder.model_block_dict.values())[0].weight.device)
    loss_dict = model.train(epochs=31, save_every=30, return_losses=True, log_wandb=True)
    # wandb.log(loss_dict)
    return loss_dict['zero_loss']
    
def main(noise):
    wandb.init(project=f"pv_hp_sweep_{noise}")
    
    if not is_valid_config(wandb.config):
        print("Skipping invalid configuration")
        wandb.log({'score': float('inf')})
        wandb.finish()
        return
    # score = objective(wandb.config)
    score = train_model(wandb.config, noise)
    wandb.log({'score': score})
    wandb.finish()

# %%
# noise = 10
# # Create sweep with ID: ojd94845
# # Sweep URL: https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/ojd94845
# wandb.agent('ojd94845', 
#             function=lambda: main(noise=noise),
#             project=f"pv_grid_sweep_{noise}")

# %%
import json
for noise in range(10,15):
    # sweep_id = json.load(open('sweep_ids.json'))[str(noise)]
    sweep_id = wandb.sweep(sweep=sweep_configuration, project=f"pv_grid_sweep_{noise}")
    wandb.agent(sweep_id, function=lambda: main(noise=noise))
# Out:
# Create sweep with ID: uucn68pw
# Sweep URL: https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw
# wandb: Agent Starting Run: 9pcpuxcx with config:
# wandb: 	gaussian_std: 1
# wandb: 	hidden_x1_depth: 1
# wandb: 	hidden_x2_depth: 1
# wandb: 	hidden_xfc_depth: 1
# wandb: 	lr: 1e-05
# wandb: 	num_fits: 2
# wandb: 	num_neighbors: 4
# wandb: 	scaling_kernel_size: 1
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Ignoring project 'pv_hp_sweep_10' when running a sweep.
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/home/xz498/Gaussian_Sampler/Notebooks/wandb/run-20250513_163846-9pcpuxcx</code>
# Syncing run <strong><a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/9pcpuxcx' target="_blank">exalted-sweep-1</a></strong> to <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw</a>
#  View project at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10</a>
#  View sweep at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw</a>
#  View run at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/9pcpuxcx' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/9pcpuxcx</a>
# Fitting scalers for 00.500_noise, kernel size 1: 100%|██████████| 10000/10000 [00:07<00:00, 1378.31it/s]
# cuda:4
# /home/xz498/Gaussian_Sampler_Data/4/checkpoints/wandb_sweep
#  80%|████████  | 4/5 [00:04<00:01,  1.13s/it]
# Epoch: 000/031 | Train Loss: 0.0214
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 001/031 | Train Loss: 0.0212
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 002/031 | Train Loss: 0.0213
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.04s/it]
# Epoch: 003/031 | Train Loss: 0.0213
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 004/031 | Train Loss: 0.0213
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 005/031 | Train Loss: 0.0214
# .............................
#  80%|████████  | 4/5 [00:03<00:00,  1.00it/s]
# Epoch: 006/031 | Train Loss: 0.0213
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 007/031 | Train Loss: 0.0214
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 008/031 | Train Loss: 0.0214
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 009/031 | Train Loss: 0.0212
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 010/031 | Train Loss: 0.0213
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 011/031 | Train Loss: 0.0214
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 012/031 | Train Loss: 0.0214
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 013/031 | Train Loss: 0.0213
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 014/031 | Train Loss: 0.0214
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 015/031 | Train Loss: 0.0214
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 016/031 | Train Loss: 0.0215
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.04s/it]
# Epoch: 017/031 | Train Loss: 0.0215
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.08s/it]
# Epoch: 018/031 | Train Loss: 0.0213
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.04s/it]
# Epoch: 019/031 | Train Loss: 0.0214
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.05s/it]
# Epoch: 020/031 | Train Loss: 0.0213
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.04s/it]
# Epoch: 021/031 | Train Loss: 0.0214
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 022/031 | Train Loss: 0.0213
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.04s/it]
# Epoch: 023/031 | Train Loss: 0.0214
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 024/031 | Train Loss: 0.0214
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.10s/it]
# Epoch: 025/031 | Train Loss: 0.0214
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.04s/it]
# Epoch: 026/031 | Train Loss: 0.0214
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.05s/it]
# Epoch: 027/031 | Train Loss: 0.0213
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.04s/it]
# Epoch: 028/031 | Train Loss: 0.0214
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 029/031 | Train Loss: 0.0213
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.04s/it]
# Epoch: 030/031 | Train Loss: 0.0212
# .............................
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>l2_batchwise_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mse_loss</td><td>▄▁▃▄▄▅▃▅▅▂▃▅▅▃▅▅▇█▃▅▄▅▄▅▆▅▆▃▅▃▁</td></tr><tr><td>score</td><td>▁</td></tr><tr><td>sparse_max_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>▄▁▃▄▄▅▃▅▅▂▃▅▅▃▅▅▇█▃▅▄▅▄▅▆▅▆▃▅▃▁</td></tr><tr><td>weighted_ln_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>zero_loss</td><td>▅▁▅▃▇▅▄▆▃▄▅▄▆▃▆▄▅█▅▇▆▆▅▄▅▆▆▄▅▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>l2_batchwise_loss</td><td>0</td></tr><tr><td>mse_loss</td><td>0.02121</td></tr><tr><td>score</td><td>0.00214</td></tr><tr><td>sparse_max_loss</td><td>0</td></tr><tr><td>train_loss</td><td>0.02121</td></tr><tr><td>weighted_ln_loss</td><td>0</td></tr><tr><td>zero_loss</td><td>0.00214</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">exalted-sweep-1</strong> at: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/9pcpuxcx' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/9pcpuxcx</a><br> View project at: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250513_163846-9pcpuxcx/logs</code>
# wandb: Agent Starting Run: qgk307zl with config:
# wandb: 	gaussian_std: 1
# wandb: 	hidden_x1_depth: 1
# wandb: 	hidden_x2_depth: 1
# wandb: 	hidden_xfc_depth: 1
# wandb: 	lr: 1e-05
# wandb: 	num_fits: 2
# wandb: 	num_neighbors: 4
# wandb: 	scaling_kernel_size: 3
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Ignoring project 'pv_hp_sweep_10' when running a sweep.
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/home/xz498/Gaussian_Sampler/Notebooks/wandb/run-20250513_164108-qgk307zl</code>
# Syncing run <strong><a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/qgk307zl' target="_blank">whole-sweep-2</a></strong> to <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw</a>
#  View project at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10</a>
#  View sweep at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw</a>
#  View run at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/qgk307zl' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/qgk307zl</a>
# Fitting scalers for 00.500_noise, kernel size 3: 100%|██████████| 10000/10000 [00:08<00:00, 1122.37it/s]
# cuda:4
# /home/xz498/Gaussian_Sampler_Data/4/checkpoints/wandb_sweep
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 000/031 | Train Loss: 0.0091
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.00s/it]
# Epoch: 001/031 | Train Loss: 0.0085
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 002/031 | Train Loss: 0.0084
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 003/031 | Train Loss: 0.0082
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 004/031 | Train Loss: 0.0083
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.05s/it]
# Epoch: 005/031 | Train Loss: 0.0082
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 006/031 | Train Loss: 0.0082
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.05s/it]
# Epoch: 007/031 | Train Loss: 0.0083
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 008/031 | Train Loss: 0.0081
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 009/031 | Train Loss: 0.0080
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.06s/it]
# Epoch: 010/031 | Train Loss: 0.0080
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 011/031 | Train Loss: 0.0081
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.00s/it]
# Epoch: 012/031 | Train Loss: 0.0080
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 013/031 | Train Loss: 0.0079
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.09s/it]
# Epoch: 014/031 | Train Loss: 0.0080
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 015/031 | Train Loss: 0.0079
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 016/031 | Train Loss: 0.0079
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 017/031 | Train Loss: 0.0079
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 018/031 | Train Loss: 0.0078
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.00s/it]
# Epoch: 019/031 | Train Loss: 0.0079
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 020/031 | Train Loss: 0.0078
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 021/031 | Train Loss: 0.0077
# .............................
#  80%|████████  | 4/5 [00:03<00:00,  1.01it/s]
# Epoch: 022/031 | Train Loss: 0.0077
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 023/031 | Train Loss: 0.0077
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 024/031 | Train Loss: 0.0076
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 025/031 | Train Loss: 0.0077
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 026/031 | Train Loss: 0.0076
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 027/031 | Train Loss: 0.0074
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.06s/it]
# Epoch: 028/031 | Train Loss: 0.0075
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.05s/it]
# Epoch: 029/031 | Train Loss: 0.0073
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.07s/it]
# Epoch: 030/031 | Train Loss: 0.0073
# .............................
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>l2_batchwise_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mse_loss</td><td>█▆▅▅▅▅▅▅▄▄▄▄▄▄▄▃▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁</td></tr><tr><td>score</td><td>▁</td></tr><tr><td>sparse_max_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▆▅▅▅▅▅▅▄▄▄▄▄▄▄▃▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁</td></tr><tr><td>weighted_ln_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>zero_loss</td><td>▂▁▂▁▂▂▂▃▃▄▅▅▆▆▇▇▇█▇██▇▇▇▇▇▇▇█▇▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>l2_batchwise_loss</td><td>0</td></tr><tr><td>mse_loss</td><td>0.00727</td></tr><tr><td>score</td><td>0.00343</td></tr><tr><td>sparse_max_loss</td><td>0</td></tr><tr><td>train_loss</td><td>0.00727</td></tr><tr><td>weighted_ln_loss</td><td>0</td></tr><tr><td>zero_loss</td><td>0.00343</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">whole-sweep-2</strong> at: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/qgk307zl' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/qgk307zl</a><br> View project at: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250513_164108-qgk307zl/logs</code>
# wandb: Agent Starting Run: 1zyxlvkn with config:
# wandb: 	gaussian_std: 1
# wandb: 	hidden_x1_depth: 1
# wandb: 	hidden_x2_depth: 1
# wandb: 	hidden_xfc_depth: 1
# wandb: 	lr: 1e-05
# wandb: 	num_fits: 2
# wandb: 	num_neighbors: 4
# wandb: 	scaling_kernel_size: 5
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Ignoring project 'pv_hp_sweep_10' when running a sweep.
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/home/xz498/Gaussian_Sampler/Notebooks/wandb/run-20250513_164330-1zyxlvkn</code>
# Syncing run <strong><a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/1zyxlvkn' target="_blank">cosmic-sweep-3</a></strong> to <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw</a>
#  View project at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10</a>
#  View sweep at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw</a>
#  View run at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/1zyxlvkn' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/1zyxlvkn</a>
# Fitting scalers for 00.500_noise, kernel size 5: 100%|██████████| 10000/10000 [00:09<00:00, 1027.42it/s]
# cuda:4
# /home/xz498/Gaussian_Sampler_Data/4/checkpoints/wandb_sweep
#  80%|████████  | 4/5 [00:04<00:01,  1.07s/it]
# Epoch: 000/031 | Train Loss: 0.0084
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 001/031 | Train Loss: 0.0077
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.12s/it]
# Epoch: 002/031 | Train Loss: 0.0075
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 003/031 | Train Loss: 0.0072
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 004/031 | Train Loss: 0.0073
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 005/031 | Train Loss: 0.0072
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 006/031 | Train Loss: 0.0072
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 007/031 | Train Loss: 0.0073
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 008/031 | Train Loss: 0.0071
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 009/031 | Train Loss: 0.0070
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 010/031 | Train Loss: 0.0070
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.04s/it]
# Epoch: 011/031 | Train Loss: 0.0071
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 012/031 | Train Loss: 0.0070
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 013/031 | Train Loss: 0.0070
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 014/031 | Train Loss: 0.0070
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 015/031 | Train Loss: 0.0069
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 016/031 | Train Loss: 0.0070
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 017/031 | Train Loss: 0.0070
# .............................
#  80%|████████  | 4/5 [00:03<00:00,  1.00it/s]
# Epoch: 018/031 | Train Loss: 0.0069
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 019/031 | Train Loss: 0.0070
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 020/031 | Train Loss: 0.0069
# .............................
#  80%|████████  | 4/5 [00:03<00:00,  1.00it/s]
# Epoch: 021/031 | Train Loss: 0.0068
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 022/031 | Train Loss: 0.0068
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 023/031 | Train Loss: 0.0068
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 024/031 | Train Loss: 0.0067
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 025/031 | Train Loss: 0.0068
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 026/031 | Train Loss: 0.0067
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 027/031 | Train Loss: 0.0066
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 028/031 | Train Loss: 0.0067
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.04s/it]
# Epoch: 029/031 | Train Loss: 0.0065
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 030/031 | Train Loss: 0.0065
# .............................
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>l2_batchwise_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mse_loss</td><td>█▆▅▄▄▄▄▄▃▃▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▁▂▁▁</td></tr><tr><td>score</td><td>▁</td></tr><tr><td>sparse_max_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▆▅▄▄▄▄▄▃▃▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▁▂▁▁</td></tr><tr><td>weighted_ln_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>zero_loss</td><td>▂▁▂▁▂▂▂▃▂▃▄▄▅▅▆▆▇█▇██▇▇▇▇█▇▇▇▆▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>l2_batchwise_loss</td><td>0</td></tr><tr><td>mse_loss</td><td>0.00651</td></tr><tr><td>score</td><td>0.00294</td></tr><tr><td>sparse_max_loss</td><td>0</td></tr><tr><td>train_loss</td><td>0.00651</td></tr><tr><td>weighted_ln_loss</td><td>0</td></tr><tr><td>zero_loss</td><td>0.00294</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">cosmic-sweep-3</strong> at: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/1zyxlvkn' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/1zyxlvkn</a><br> View project at: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250513_164330-1zyxlvkn/logs</code>
# wandb: Agent Starting Run: 61ttw1m5 with config:
# wandb: 	gaussian_std: 1
# wandb: 	hidden_x1_depth: 1
# wandb: 	hidden_x2_depth: 1
# wandb: 	hidden_xfc_depth: 1
# wandb: 	lr: 1e-05
# wandb: 	num_fits: 2
# wandb: 	num_neighbors: 8
# wandb: 	scaling_kernel_size: 1
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Ignoring project 'pv_hp_sweep_10' when running a sweep.
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/home/xz498/Gaussian_Sampler/Notebooks/wandb/run-20250513_164552-61ttw1m5</code>
# Syncing run <strong><a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/61ttw1m5' target="_blank">vibrant-sweep-4</a></strong> to <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw</a>
#  View project at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10</a>
#  View sweep at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw</a>
#  View run at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/61ttw1m5' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/61ttw1m5</a>
# Fitting scalers for 00.500_noise, kernel size 1: 100%|██████████| 10000/10000 [00:07<00:00, 1398.40it/s]
# cuda:4
# /home/xz498/Gaussian_Sampler_Data/4/checkpoints/wandb_sweep
#  80%|████████  | 4/5 [00:04<00:01,  1.04s/it]
# Epoch: 000/031 | Train Loss: 0.0080
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 001/031 | Train Loss: 0.0079
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 002/031 | Train Loss: 0.0080
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 003/031 | Train Loss: 0.0079
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 004/031 | Train Loss: 0.0077
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 005/031 | Train Loss: 0.0078
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 006/031 | Train Loss: 0.0077
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.06s/it]
# Epoch: 007/031 | Train Loss: 0.0076
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 008/031 | Train Loss: 0.0076
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 009/031 | Train Loss: 0.0074
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.05s/it]
# Epoch: 010/031 | Train Loss: 0.0074
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 011/031 | Train Loss: 0.0073
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 012/031 | Train Loss: 0.0073
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 013/031 | Train Loss: 0.0071
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.06s/it]
# Epoch: 014/031 | Train Loss: 0.0071
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.04s/it]
# Epoch: 015/031 | Train Loss: 0.0070
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 016/031 | Train Loss: 0.0069
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 017/031 | Train Loss: 0.0069
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 018/031 | Train Loss: 0.0068
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 019/031 | Train Loss: 0.0068
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 020/031 | Train Loss: 0.0066
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 021/031 | Train Loss: 0.0065
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.05s/it]
# Epoch: 022/031 | Train Loss: 0.0064
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.05s/it]
# Epoch: 023/031 | Train Loss: 0.0063
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 024/031 | Train Loss: 0.0063
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 025/031 | Train Loss: 0.0062
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 026/031 | Train Loss: 0.0061
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 027/031 | Train Loss: 0.0060
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 028/031 | Train Loss: 0.0060
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 029/031 | Train Loss: 0.0058
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.05s/it]
# Epoch: 030/031 | Train Loss: 0.0058
# .............................
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>l2_batchwise_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mse_loss</td><td>███▇▇▇▇▇▇▆▆▆▆▅▅▅▄▅▄▄▃▃▃▃▃▂▂▂▂▁▁</td></tr><tr><td>score</td><td>▁</td></tr><tr><td>sparse_max_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>███▇▇▇▇▇▇▆▆▆▆▅▅▅▄▅▄▄▃▃▃▃▃▂▂▂▂▁▁</td></tr><tr><td>weighted_ln_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>zero_loss</td><td>▁▁▂▂▂▃▄▄▅▅▆▇▇▇▇▇▆▇▇▇▇▇▇▇█▇▇▇█▇▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>l2_batchwise_loss</td><td>0</td></tr><tr><td>mse_loss</td><td>0.00575</td></tr><tr><td>score</td><td>0.00475</td></tr><tr><td>sparse_max_loss</td><td>0</td></tr><tr><td>train_loss</td><td>0.00575</td></tr><tr><td>weighted_ln_loss</td><td>0</td></tr><tr><td>zero_loss</td><td>0.00475</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">vibrant-sweep-4</strong> at: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/61ttw1m5' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/61ttw1m5</a><br> View project at: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250513_164552-61ttw1m5/logs</code>
# wandb: Agent Starting Run: 7nw8uxjq with config:
# wandb: 	gaussian_std: 1
# wandb: 	hidden_x1_depth: 1
# wandb: 	hidden_x2_depth: 1
# wandb: 	hidden_xfc_depth: 1
# wandb: 	lr: 1e-05
# wandb: 	num_fits: 2
# wandb: 	num_neighbors: 8
# wandb: 	scaling_kernel_size: 3
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Ignoring project 'pv_hp_sweep_10' when running a sweep.
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/home/xz498/Gaussian_Sampler/Notebooks/wandb/run-20250513_164813-7nw8uxjq</code>
# Syncing run <strong><a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/7nw8uxjq' target="_blank">feasible-sweep-5</a></strong> to <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw</a>
#  View project at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10</a>
#  View sweep at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw</a>
#  View run at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/7nw8uxjq' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/7nw8uxjq</a>
# Fitting scalers for 00.500_noise, kernel size 3: 100%|██████████| 10000/10000 [00:09<00:00, 1084.57it/s]
# cuda:4
# /home/xz498/Gaussian_Sampler_Data/4/checkpoints/wandb_sweep
#  80%|████████  | 4/5 [00:04<00:01,  1.06s/it]
# Epoch: 000/031 | Train Loss: 0.0109
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 001/031 | Train Loss: 0.0103
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 002/031 | Train Loss: 0.0099
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 003/031 | Train Loss: 0.0093
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 004/031 | Train Loss: 0.0088
# .............................
#  80%|████████  | 4/5 [00:03<00:00,  1.00it/s]
# Epoch: 005/031 | Train Loss: 0.0084
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 006/031 | Train Loss: 0.0080
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 007/031 | Train Loss: 0.0074
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.00s/it]
# Epoch: 008/031 | Train Loss: 0.0071
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 009/031 | Train Loss: 0.0068
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 010/031 | Train Loss: 0.0065
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 011/031 | Train Loss: 0.0063
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 012/031 | Train Loss: 0.0062
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.00s/it]
# Epoch: 013/031 | Train Loss: 0.0057
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.00s/it]
# Epoch: 014/031 | Train Loss: 0.0057
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 015/031 | Train Loss: 0.0056
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 016/031 | Train Loss: 0.0055
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 017/031 | Train Loss: 0.0055
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 018/031 | Train Loss: 0.0054
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.00s/it]
# Epoch: 019/031 | Train Loss: 0.0054
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.00s/it]
# Epoch: 020/031 | Train Loss: 0.0052
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 021/031 | Train Loss: 0.0052
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.00s/it]
# Epoch: 022/031 | Train Loss: 0.0052
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.00s/it]
# Epoch: 023/031 | Train Loss: 0.0051
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 024/031 | Train Loss: 0.0053
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.00s/it]
# Epoch: 025/031 | Train Loss: 0.0051
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.00s/it]
# Epoch: 026/031 | Train Loss: 0.0051
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 027/031 | Train Loss: 0.0052
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.04s/it]
# Epoch: 028/031 | Train Loss: 0.0053
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.06s/it]
# Epoch: 029/031 | Train Loss: 0.0050
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.06s/it]
# Epoch: 030/031 | Train Loss: 0.0051
# .............................
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>l2_batchwise_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mse_loss</td><td>█▇▇▆▅▅▅▄▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>score</td><td>▁</td></tr><tr><td>sparse_max_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▇▇▆▅▅▅▄▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>weighted_ln_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>zero_loss</td><td>▂▃▅▄▄▅▆▃▄▃▅▅▆▁▂▄▂▆▃▄▂▃▆▁▇▄▄▅█▃▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>l2_batchwise_loss</td><td>0</td></tr><tr><td>mse_loss</td><td>0.00509</td></tr><tr><td>score</td><td>0.00202</td></tr><tr><td>sparse_max_loss</td><td>0</td></tr><tr><td>train_loss</td><td>0.00509</td></tr><tr><td>weighted_ln_loss</td><td>0</td></tr><tr><td>zero_loss</td><td>0.00202</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">feasible-sweep-5</strong> at: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/7nw8uxjq' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/7nw8uxjq</a><br> View project at: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250513_164813-7nw8uxjq/logs</code>
# wandb: Agent Starting Run: yer7hol5 with config:
# wandb: 	gaussian_std: 1
# wandb: 	hidden_x1_depth: 1
# wandb: 	hidden_x2_depth: 1
# wandb: 	hidden_xfc_depth: 1
# wandb: 	lr: 1e-05
# wandb: 	num_fits: 2
# wandb: 	num_neighbors: 8
# wandb: 	scaling_kernel_size: 5
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Ignoring project 'pv_hp_sweep_10' when running a sweep.
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/home/xz498/Gaussian_Sampler/Notebooks/wandb/run-20250513_165037-yer7hol5</code>
# Syncing run <strong><a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/yer7hol5' target="_blank">generous-sweep-6</a></strong> to <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw</a>
#  View project at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10</a>
#  View sweep at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw</a>
#  View run at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/yer7hol5' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/yer7hol5</a>
# Fitting scalers for 00.500_noise, kernel size 5: 100%|██████████| 10000/10000 [00:10<00:00, 959.97it/s]
# cuda:4
# /home/xz498/Gaussian_Sampler_Data/4/checkpoints/wandb_sweep
#  80%|████████  | 4/5 [00:04<00:01,  1.10s/it]
# Epoch: 000/031 | Train Loss: 0.0094
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.05s/it]
# Epoch: 001/031 | Train Loss: 0.0089
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.05s/it]
# Epoch: 002/031 | Train Loss: 0.0085
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.06s/it]
# Epoch: 003/031 | Train Loss: 0.0079
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.05s/it]
# Epoch: 004/031 | Train Loss: 0.0074
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.07s/it]
# Epoch: 005/031 | Train Loss: 0.0071
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.07s/it]
# Epoch: 006/031 | Train Loss: 0.0068
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.08s/it]
# Epoch: 007/031 | Train Loss: 0.0062
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.05s/it]
# Epoch: 008/031 | Train Loss: 0.0060
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.07s/it]
# Epoch: 009/031 | Train Loss: 0.0057
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.08s/it]
# Epoch: 010/031 | Train Loss: 0.0054
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.08s/it]
# Epoch: 011/031 | Train Loss: 0.0053
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.07s/it]
# Epoch: 012/031 | Train Loss: 0.0053
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 013/031 | Train Loss: 0.0049
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 014/031 | Train Loss: 0.0048
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.06s/it]
# Epoch: 015/031 | Train Loss: 0.0048
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.06s/it]
# Epoch: 016/031 | Train Loss: 0.0047
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.07s/it]
# Epoch: 017/031 | Train Loss: 0.0048
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.09s/it]
# Epoch: 018/031 | Train Loss: 0.0047
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.06s/it]
# Epoch: 019/031 | Train Loss: 0.0046
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.07s/it]
# Epoch: 020/031 | Train Loss: 0.0045
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.08s/it]
# Epoch: 021/031 | Train Loss: 0.0045
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.05s/it]
# Epoch: 022/031 | Train Loss: 0.0045
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.07s/it]
# Epoch: 023/031 | Train Loss: 0.0045
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.05s/it]
# Epoch: 024/031 | Train Loss: 0.0046
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 025/031 | Train Loss: 0.0045
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.04s/it]
# Epoch: 026/031 | Train Loss: 0.0044
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.04s/it]
# Epoch: 027/031 | Train Loss: 0.0045
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.05s/it]
# Epoch: 028/031 | Train Loss: 0.0046
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.08s/it]
# Epoch: 029/031 | Train Loss: 0.0044
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.06s/it]
# Epoch: 030/031 | Train Loss: 0.0045
# .............................
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>l2_batchwise_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mse_loss</td><td>█▇▇▆▅▅▄▄▃▃▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>score</td><td>▁</td></tr><tr><td>sparse_max_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▇▇▆▅▅▄▄▃▃▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>weighted_ln_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>zero_loss</td><td>▂▃▅▄▅▅▆▃▄▂▅▅▆▁▂▃▂▆▃▄▂▃▆▁▇▄▃▄█▃▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>l2_batchwise_loss</td><td>0</td></tr><tr><td>mse_loss</td><td>0.00447</td></tr><tr><td>score</td><td>0.00177</td></tr><tr><td>sparse_max_loss</td><td>0</td></tr><tr><td>train_loss</td><td>0.00447</td></tr><tr><td>weighted_ln_loss</td><td>0</td></tr><tr><td>zero_loss</td><td>0.00177</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">generous-sweep-6</strong> at: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/yer7hol5' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/yer7hol5</a><br> View project at: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250513_165037-yer7hol5/logs</code>
# wandb: Agent Starting Run: k8ojvo94 with config:
# wandb: 	gaussian_std: 1
# wandb: 	hidden_x1_depth: 1
# wandb: 	hidden_x2_depth: 1
# wandb: 	hidden_xfc_depth: 1
# wandb: 	lr: 1e-05
# wandb: 	num_fits: 2
# wandb: 	num_neighbors: 12
# wandb: 	scaling_kernel_size: 1
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Ignoring project 'pv_hp_sweep_10' when running a sweep.
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/home/xz498/Gaussian_Sampler/Notebooks/wandb/run-20250513_165304-k8ojvo94</code>
# Syncing run <strong><a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/k8ojvo94' target="_blank">dark-sweep-7</a></strong> to <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw</a>
#  View project at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10</a>
#  View sweep at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw</a>
#  View run at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/k8ojvo94' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/k8ojvo94</a>
# Skipping invalid configuration
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>score</td><td>inf</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dark-sweep-7</strong> at: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/k8ojvo94' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/k8ojvo94</a><br> View project at: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250513_165304-k8ojvo94/logs</code>
# wandb: Agent Starting Run: t9muy67u with config:
# wandb: 	gaussian_std: 1
# wandb: 	hidden_x1_depth: 1
# wandb: 	hidden_x2_depth: 1
# wandb: 	hidden_xfc_depth: 1
# wandb: 	lr: 1e-05
# wandb: 	num_fits: 2
# wandb: 	num_neighbors: 12
# wandb: 	scaling_kernel_size: 3
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Ignoring project 'pv_hp_sweep_10' when running a sweep.
# Waiting for wandb.init()...
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/home/xz498/Gaussian_Sampler/Notebooks/wandb/run-20250513_165310-t9muy67u</code>
# Syncing run <strong><a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/t9muy67u' target="_blank">crimson-sweep-8</a></strong> to <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw</a>
#  View project at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10</a>
#  View sweep at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw</a>
#  View run at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/t9muy67u' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/t9muy67u</a>
# Skipping invalid configuration
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>score</td><td>inf</td></tr></table><br/></div></div>
# ...
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 022/031 | Train Loss: 0.0129
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 023/031 | Train Loss: 0.0126
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 024/031 | Train Loss: 0.0131
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 025/031 | Train Loss: 0.0128
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# Epoch: 026/031 | Train Loss: 0.0128
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 027/031 | Train Loss: 0.0129
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 028/031 | Train Loss: 0.0132
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 029/031 | Train Loss: 0.0126
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.05s/it]
# Epoch: 030/031 | Train Loss: 0.0129
# .............................
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>l2_batchwise_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mse_loss</td><td>▂▃▅▄▅▅▆▃▄▄▄▅▆▁▃▄▃▅▄▄▃▃▅▂▇▄▃▄█▂▅</td></tr><tr><td>score</td><td>▁</td></tr><tr><td>sparse_max_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>▂▃▅▄▅▅▆▃▄▄▄▅▆▁▃▄▃▅▄▄▃▃▅▂▇▄▃▄█▂▅</td></tr><tr><td>weighted_ln_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>zero_loss</td><td>▂▃▅▄▄▅▆▃▄▃▅▅▆▁▂▄▂▆▃▄▂▃▆▁▇▄▄▅█▃▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>l2_batchwise_loss</td><td>0</td></tr><tr><td>mse_loss</td><td>0.01293</td></tr><tr><td>score</td><td>0.00202</td></tr><tr><td>sparse_max_loss</td><td>0</td></tr><tr><td>train_loss</td><td>0.01293</td></tr><tr><td>weighted_ln_loss</td><td>0</td></tr><tr><td>zero_loss</td><td>0.00202</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">worldly-sweep-149</strong> at: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/lc9uha8e' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/lc9uha8e</a><br> View project at: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250513_195205-lc9uha8e/logs</code>
# wandb: Agent Starting Run: 684qktk7 with config:
# wandb: 	gaussian_std: 1
# wandb: 	hidden_x1_depth: 1
# wandb: 	hidden_x2_depth: 1
# wandb: 	hidden_xfc_depth: 2
# wandb: 	lr: 5e-05
# wandb: 	num_fits: 2
# wandb: 	num_neighbors: 8
# wandb: 	scaling_kernel_size: 5
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Ignoring project 'pv_hp_sweep_10' when running a sweep.
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/home/xz498/Gaussian_Sampler/Notebooks/wandb/run-20250513_195427-684qktk7</code>
# Syncing run <strong><a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/684qktk7' target="_blank">driven-sweep-150</a></strong> to <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw</a>
#  View project at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10</a>
#  View sweep at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw</a>
#  View run at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/684qktk7' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/684qktk7</a>
# Fitting scalers for 00.500_noise, kernel size 5: 100%|██████████| 10000/10000 [00:09<00:00, 1014.42it/s]
# cuda:4
# /home/xz498/Gaussian_Sampler_Data/4/checkpoints/wandb_sweep
#  80%|████████  | 4/5 [00:04<00:01,  1.04s/it]
# Epoch: 000/031 | Train Loss: 0.0111
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 001/031 | Train Loss: 0.0112
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 002/031 | Train Loss: 0.0113
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 003/031 | Train Loss: 0.0113
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 004/031 | Train Loss: 0.0113
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 005/031 | Train Loss: 0.0114
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 006/031 | Train Loss: 0.0114
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 007/031 | Train Loss: 0.0111
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 008/031 | Train Loss: 0.0112
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 009/031 | Train Loss: 0.0112
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 010/031 | Train Loss: 0.0111
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 011/031 | Train Loss: 0.0113
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 012/031 | Train Loss: 0.0114
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 013/031 | Train Loss: 0.0110
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 014/031 | Train Loss: 0.0111
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 015/031 | Train Loss: 0.0112
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 016/031 | Train Loss: 0.0111
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 017/031 | Train Loss: 0.0113
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 018/031 | Train Loss: 0.0113
# .............................
#  80%|████████  | 4/5 [00:03<00:00,  1.00it/s]
# Epoch: 019/031 | Train Loss: 0.0113
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 020/031 | Train Loss: 0.0112
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 021/031 | Train Loss: 0.0111
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 022/031 | Train Loss: 0.0113
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 023/031 | Train Loss: 0.0111
# .............................
#  80%|████████  | 4/5 [00:03<00:00,  1.00it/s]
# Epoch: 024/031 | Train Loss: 0.0114
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 025/031 | Train Loss: 0.0113
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 026/031 | Train Loss: 0.0111
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.00s/it]
# Epoch: 027/031 | Train Loss: 0.0112
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.01s/it]
# Epoch: 028/031 | Train Loss: 0.0115
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.02s/it]
# Epoch: 029/031 | Train Loss: 0.0111
# .............................
#  80%|████████  | 4/5 [00:04<00:01,  1.00s/it]
# Epoch: 030/031 | Train Loss: 0.0113
# .............................
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>l2_batchwise_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mse_loss</td><td>▂▃▅▄▅▆▇▃▄▃▃▅▇▁▃▃▃▅▄▅▃▂▅▂▆▄▃▃█▂▆</td></tr><tr><td>score</td><td>▁</td></tr><tr><td>sparse_max_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>▂▃▅▄▅▆▇▃▄▃▃▅▇▁▃▃▃▅▄▅▃▂▅▂▆▄▃▃█▂▆</td></tr><tr><td>weighted_ln_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>zero_loss</td><td>▂▃▅▄▅▅▆▃▄▂▅▅▆▁▂▃▂▆▃▄▂▃▆▁▇▄▃▄█▃▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>l2_batchwise_loss</td><td>0</td></tr><tr><td>mse_loss</td><td>0.01135</td></tr><tr><td>score</td><td>0.00177</td></tr><tr><td>sparse_max_loss</td><td>0</td></tr><tr><td>train_loss</td><td>0.01135</td></tr><tr><td>weighted_ln_loss</td><td>0</td></tr><tr><td>zero_loss</td><td>0.00177</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">driven-sweep-150</strong> at: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/684qktk7' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/684qktk7</a><br> View project at: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250513_195427-684qktk7/logs</code>
# wandb: Agent Starting Run: dnbeoo8m with config:
# wandb: 	gaussian_std: 1
# wandb: 	hidden_x1_depth: 1
# wandb: 	hidden_x2_depth: 1
# wandb: 	hidden_xfc_depth: 2
# wandb: 	lr: 5e-05
# wandb: 	num_fits: 2
# wandb: 	num_neighbors: 12
# wandb: 	scaling_kernel_size: 1
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Ignoring project 'pv_hp_sweep_10' when running a sweep.
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/home/xz498/Gaussian_Sampler/Notebooks/wandb/run-20250513_195649-dnbeoo8m</code>
# Syncing run <strong><a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/dnbeoo8m' target="_blank">generous-sweep-151</a></strong> to <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw</a>
#  View project at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10</a>
#  View sweep at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw</a>
#  View run at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/dnbeoo8m' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/dnbeoo8m</a>
# Skipping invalid configuration
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>score</td><td>inf</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">generous-sweep-151</strong> at: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/dnbeoo8m' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/dnbeoo8m</a><br> View project at: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250513_195649-dnbeoo8m/logs</code>
# wandb: Agent Starting Run: m1w520hp with config:
# wandb: 	gaussian_std: 1
# wandb: 	hidden_x1_depth: 1
# wandb: 	hidden_x2_depth: 1
# wandb: 	hidden_xfc_depth: 2
# wandb: 	lr: 5e-05
# wandb: 	num_fits: 2
# wandb: 	num_neighbors: 12
# wandb: 	scaling_kernel_size: 3
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Ignoring project 'pv_hp_sweep_10' when running a sweep.
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/home/xz498/Gaussian_Sampler/Notebooks/wandb/run-20250513_195725-m1w520hp</code>
# Syncing run <strong><a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/m1w520hp' target="_blank">azure-sweep-152</a></strong> to <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw</a>
#  View project at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10</a>
#  View sweep at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/sweeps/uucn68pw</a>
#  View run at <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/m1w520hp' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/m1w520hp</a>
# Skipping invalid configuration
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>score</td><td>inf</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">azure-sweep-152</strong> at: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/m1w520hp' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10/runs/m1w520hp</a><br> View project at: <a href='https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10' target="_blank">https://wandb.ai/zhang-xinqiao/pv_grid_sweep_10</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250513_195725-m1w520hp/logs</code>
# wandb: Agent Starting Run: bw7nk4q1 with config:
# wandb: 	gaussian_std: 1
# wandb: 	hidden_x1_depth: 1
# wandb: 	hidden_x2_depth: 1
# wandb: 	hidden_xfc_depth: 2
# wandb: 	lr: 5e-05
# wandb: 	num_fits: 2
# wandb: 	num_neighbors: 12
# wandb: 	scaling_kernel_size: 5
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Ignoring project 'pv_hp_sweep_10' when running a sweep.
