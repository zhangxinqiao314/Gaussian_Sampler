# %% [markdown]
# # Utility/imports

# %%
import wandb

# 1. Initialize API
api = wandb.Api()

# 2. Get the specific run (format: "entity/project/run_id")
runs = api.runs("zhang-xinqiao/Gaussian_Sampler-Notebooks", filters={"tags": {"$ne": "hidden"}})
# Out:
# wandb: Currently logged in as: zhang-xinqiao to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
# Iterate over runs and print details
for run in runs:
    run.config["noise_level"] = int(run.config['name'].split('_')[0])
    if run.config['sampling_type'] == 'random':
        run.config.pop("gaussian_std")
        run.config.pop("num_neighbors")
        print(f"Run config: {run.config}")
        print("----------")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 5
#       3 run.config["noise_level"] = int(run.config['name'].split('_')[0])
#       4 if run.config['sampling_type'] == 'random':
# ----> 5     run.config.pop("gaussian_std")
#       6     run.config.pop("num_neighbors")
#       7     print(f"Run config: {run.config}")
#
# KeyError: 'gaussian_std'

# %%
# 4. Save the changes back to W&B
run.update()

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from tqdm import tqdm

import h5py

import holoviews as hv
import panel as pn

hv.extension('bokeh')
pn.extension('bokeh')

import h5py

import torch
import glob

import sys
sys.path.append('..') # path to the src directory
sys.path.append('/home/xinqiao/new_mount/gaussian_sampler/M3Learning-Util/src')
sys.path.append('/home/xinqiao/new_mount/gaussian_sampler/AutoPhysLearn/src')
import wandb
import matplotlib.pyplot as plt
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='131c30eb-c7da-4df1-ba00-a360f2177c95'>
#   <div id="d1eddf90-1ea8-4912-b87f-7ea6a1181f6a" data-root-id="131c30eb-c7da-4df1-ba00-a360f2177c95" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# ## load and write data

# %%
from Gaussian_Sampler.models.pv_fitter import pseudovoigt_1D_fitters_new
fitter = pseudovoigt_1D_fitters_new(limits = [1,1,750])
# Out:
# /home/xinqiao/anaconda3/envs/gaussian_sampler/lib/python3.13/site-packages/datafed_torchflow/computer.py:5: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
from Gaussian_Sampler.data.datasets import Poisson_Sampled_PV_Dataset
from sklearn.preprocessing import Normalizer
from sklearn.pipeline import Pipeline
datapath = '/home/xinqiao/new_mount/gaussian_sampler/'

dset = Poisson_Sampled_PV_Dataset(shape=(100,100,750),
                       save_folder=datapath+'toy_dataset/max_norm/',
                       pv_fitter=fitter,
                       num_classes=5,
                       num_curves=3,
                       scaler=Normalizer(norm='max'),
                    #    overwrite=True,
                       norm_calculation=lambda x: np.linalg.norm(x, axis=-1, ord=np.inf),
                       )

# %%
with dset.open_h5_file() as f:
    print(f['scaled'].keys())
# Out:
# <KeysViewHDF5 ['00_01.000_sample_rate', '01_00.794_sample_rate', '02_00.631_sample_rate', '03_00.501_sample_rate', '04_00.398_sample_rate', '05_00.316_sample_rate', '06_00.251_sample_rate', '07_00.200_sample_rate', '08_00.158_sample_rate', '09_00.126_sample_rate']>

# %%
# dset._write_scaled_dataset()

# %% [markdown]
# ## Visualize input and sampler

# %%
from Gaussian_Sampler.data.custom_sampler import Gaussian_Sampler
sampler = Gaussian_Sampler(dset, batch_size=100, orig_shape=dset.shape[0:-1], 
                           # TEST: gaussian std
                           gaussian_std=3, 
                           # TEST: num neighbors
                           num_neighbors=10)
batch_inds = next(iter(sampler))

# %%
from Gaussian_Sampler.viz.plotly_viz import Poisson_Sampled_PV_viz

viz = Poisson_Sampled_PV_viz(dset, sampler)
# viz = Poisson_Sampled_PV_viz(dset)

# %% [markdown]
# #### The following cell displays an example of the training data
# - Left side is the image dimension. The red spot is the location where the signal is displayed.
# - Right side is the spectral dimension. The black line is the spectra where the image is displayed. The red signal is signal without noise. The blue signal is with uniform gaussian noise.

# %%
input_viz = viz.layout_input()
input_viz

# %% [markdown]
# #### The following cell displays signals from the gaussian sampled batches
# - Checkboxes correspond to the sampled minibatches. Each minibatch has a corresponding color
# - Left side is the image dimension. The red spot is the location where the signal is displayed. The colored spots are the sampled minibatch
# - Right side is the spectral dimension. The black line is the spectra where the image is displayed. The red signal is signal without noise. The blue signal is with uniform gaussian noise. The color signals are corresponding minibatches, averaged out.

# %%
batch_viz = viz.layout_batch()
batch_viz
# pane = batch_viz.show(port=5006, )
                      #websocket_origin="*",threaded=True)

# %% [markdown]
# ## Test model

# %%
from Gaussian_Sampler.models.pv_fitter import Fitter_AE, pseudovoigt_1D_fitters_new
from autophyslearn.spectroscopic.nn import block_factory, Conv_Block, FC_Block
from autophyslearn.spectroscopic.nn import Multiscale1DFitter
from Gaussian_Sampler.data.custom_sampler import Gaussian_Sampler
num_fits = 16 # number of curves to sum up
num_params = 4 # number of parameters to fit
# todo: change wandb naming to include noise leve, group and regularization technique
# todo: test more num fits
model = Fitter_AE(function=pseudovoigt_1D_fitters_new,
                dset=dset,
                num_params=num_params,
                num_fits=num_fits,
                checkpoints_label='gaussian_sampler',
                input_channels = 1,
                learning_rate=5e-6,
                device='cuda:0',
                encoder = Multiscale1DFitter,
                encoder_params = {
                    "model_block_dict": { # factory wrapper for blocks
                            "hidden_x1": block_factory(Conv_Block)(output_channels_list=[128,64,32], 
                                                                    kernel_size_list=[3,3,3], 
                                                                    pool_list=[128,64], 
                                                                    max_pool=False),
                            "hidden_xfc": block_factory(FC_Block)(output_size_list=[64,32]),
                            "hidden_x2": block_factory(Conv_Block)(output_channels_list=[32,16,8], 
                                                                    kernel_size_list=[3,3,3], 
                                                                    pool_list=[64,32], 
                                                                    max_pool=True),
                            "hidden_embedding": block_factory(FC_Block)(output_size_list=[8*num_fits,num_params*num_fits], last=True),
                        },
                        # TEST: LIMITS,
                        "skip_connections": {'hidden_xfc': 'hidden_embedding'},
                        "function_kwargs": {'limits': [1,dset.shape[-1],dset.shape[-1]] }
                    },
                    sampler = Gaussian_Sampler,
                    sampler_params = {'dset': dset, 
                                        'batch_size': 100, 
                                        'gaussian_std': 3, 
                                        'orig_shape': dset.shape[0:-1], 
                                        'num_neighbors': 10, },
                )

# %% [markdown]
# ### make graph for model

# %%
from torchview import draw_graph
x = torch.Tensor(dset[2346][1]).reshape(-1,1,dset.spec_len).float().to('cuda:0')
# TODO: why does this not work? try installing from pip instead of git clone
# model_graph = draw_graph(fitter.encoder, input_data=x,
#                          expand_nested=True,
#                          hide_module_function=True,
#                          hide_inner_tensors=True, format="png"
#                          );

model_graph = draw_graph(model.encoder, input_data=x, 
                         save_graph=True,
                         filename="model_visualization_torchview",
                         directory="./",)

model_graph.visual_graph;

# %% [markdown]
# ### Train model for several epochs

# %%
import wandb
wandb.init()
# Out:
# wandb: Currently logged in as: zhang-xinqiao to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.0
# Run data is saved locally in <code>/home/xinqiao/new_mount/gaussian_sampler/Gaussian_Sampler/Notebooks/wandb/run-20260127_122417-92g4wzkk</code>
# Syncing run <strong><a href='https://wandb.ai/zhang-xinqiao/Gaussian_Sampler-Notebooks/runs/92g4wzkk' target="_blank">deep-music-1</a></strong> to <a href='https://wandb.ai/zhang-xinqiao/Gaussian_Sampler-Notebooks' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/zhang-xinqiao/Gaussian_Sampler-Notebooks' target="_blank">https://wandb.ai/zhang-xinqiao/Gaussian_Sampler-Notebooks</a>
#  View run at <a href='https://wandb.ai/zhang-xinqiao/Gaussian_Sampler-Notebooks/runs/92g4wzkk' target="_blank">https://wandb.ai/zhang-xinqiao/Gaussian_Sampler-Notebooks/runs/92g4wzkk</a>
# ...

# %%
import wandb
wandb.init(group='sub_sampler_type', name='sub_noise_level') # later change config for regularization
model.train(epochs=11,save_every=20, log_wandb=True)
# Out:
# Finishing previous runs because reinit is set to 'default'.
# ...

# %% [markdown]
# #### basic viz

# %%
from test_disp import training_viz
training_viz(50,60,200,dset,fitter)
# Out:
# (16,)

# %%
import test_disp
test_disp.plot_batch(fitter, dset, test_inds=[7889], noise=5)

# %% [markdown]
# ## All noise levels

# %% [markdown]
# ### Train all noise levels, gaussian sampler

# %%
from Gaussian_Sampler.models.pv_fitter import Fitter_AE, pseudovoigt_1D_fitters, pseudovoigt_1D_fitters_new
from autophyslearn.spectroscopic.nn import block_factory, Conv_Block, FC_Block
from autophyslearn.spectroscopic.nn import Multiscale1DFitter
from Gaussian_Sampler.data.custom_sampler import Gaussian_Sampler
num_fits = 16 # number of curves to sum up
num_params = 4 # number of parameters to fit
for std in [1,3,5]:
    for nn in [5,10,20]:
        for i in range(20):
            config_ = {'sampling_type': 'gaussian',
                        'name': dset.dset_name,
                        'gaussian_std': std, 
                        'num_neighbors': nn, }
            
            name = f'{i:02d}_{config_["sampling_type"]}_std:{config_["gaussian_std"]}_nn:{config_["num_neighbors"]}'
            
            dset.dset_index=i
            model = Fitter_AE(function=pseudovoigt_1D_fitters_new,
                            dset=dset,
                            num_params=num_params,
                            num_fits=num_fits,
                            checkpoints_label=name,
                            input_channels = 1,
                            learning_rate=5e-6,
                            device='cuda:0',
                            encoder = Multiscale1DFitter,
                            encoder_params = {
                                "model_block_dict": { # factory wrapper for blocks
                                        "hidden_x1": block_factory(Conv_Block)(output_channels_list=[128,64,32], 
                                                                                kernel_size_list=[3,3,3], 
                                                                                pool_list=[128,64], 
                                                                                max_pool=False),
                                        "hidden_xfc": block_factory(FC_Block)(output_size_list=[64,32]),
                                        "hidden_x2": block_factory(Conv_Block)(output_channels_list=[32,16,8], 
                                                                                kernel_size_list=[3,3,3], 
                                                                                pool_list=[64,32], 
                                                                                max_pool=True),
                                        "hidden_embedding": block_factory(FC_Block)(output_size_list=[8*num_fits,num_params*num_fits], last=True),
                                    },
                                    # TEST: LIMITS,
                                    "skip_connections": {'hidden_xfc': 'hidden_embedding'},
                                    "function_kwargs": {'limits': [1,dset.shape[-1],dset.shape[-1]] }
                                },
                                sampler = Gaussian_Sampler,
                                sampler_params = {'dset': dset, 
                                                'batch_size': 100, 
                                                'gaussian_std': std, 
                                                'orig_shape': dset.shape[0:-1], 
                                                'num_neighbors': nn },
                            )
            

            print(f'Training model for noise level {i}')
            wandb.init( name=name, config=config_) # later change config for regularization
            model.train(epochs=51,save_every=50, log_wandb=True)
# Out:
# Training model for noise level 0
# wandb: Currently logged in as: zhang-xinqiao to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.0
# Run data is saved locally in <code>/home/xinqiao/new_mount/gaussian_sampler/Gaussian_Sampler/Notebooks/wandb/run-20260204_164450-q5d80t25</code>
# Syncing run <strong><a href='https://wandb.ai/zhang-xinqiao/Gaussian_Sampler-Notebooks/runs/q5d80t25' target="_blank">00_gaussian_std:1_nn:5</a></strong> to <a href='https://wandb.ai/zhang-xinqiao/Gaussian_Sampler-Notebooks' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/zhang-xinqiao/Gaussian_Sampler-Notebooks' target="_blank">https://wandb.ai/zhang-xinqiao/Gaussian_Sampler-Notebooks</a>
# ...

# %% [markdown]
# ### Train all noise levels, random sampler

# %%
from Gaussian_Sampler.models.pv_fitter import Fitter_AE, pseudovoigt_1D_fitters, pseudovoigt_1D_fitters_new
from autophyslearn.spectroscopic.nn import block_factory, Conv_Block, FC_Block
from autophyslearn.spectroscopic.nn import Multiscale1DFitter
num_fits = 16 # number of curves to sum up
num_params = 4 # number of parameters to fit
for i in range(20):
    dset.dset_index=i
    model = Fitter_AE(function=pseudovoigt_1D_fitters_new,
                    dset=dset,
                    num_params=num_params,
                    num_fits=num_fits,
                    checkpoints_label='random_sampler',
                    input_channels = 1,
                    learning_rate=5e-6,
                    device='cuda:0',
                    encoder = Multiscale1DFitter,
                    encoder_params = {
                        "model_block_dict": { # factory wrapper for blocks
                                "hidden_x1": block_factory(Conv_Block)(output_channels_list=[128,64,32], 
                                                                        kernel_size_list=[3,3,3], 
                                                                        pool_list=[128,64], 
                                                                        max_pool=False),
                                "hidden_xfc": block_factory(FC_Block)(output_size_list=[64,32]),
                                "hidden_x2": block_factory(Conv_Block)(output_channels_list=[32,16,8], 
                                                                        kernel_size_list=[3,3,3], 
                                                                        pool_list=[64,32], 
                                                                        max_pool=True),
                                "hidden_embedding": block_factory(FC_Block)(output_size_list=[8*num_fits,num_params*num_fits], last=True),
                            },
                            # TEST: LIMITS,
                            "skip_connections": {'hidden_xfc': 'hidden_embedding'},
                            "function_kwargs": {'limits': [1,dset.shape[-1],dset.shape[-1]] }
                        },
                    )
    print(f'Training model for noise level {i}')
    wandb.init(group='random_sampler', name=dset.dset_name) # later change config for regularization
    model.train(epochs=51,save_every=10, log_wandb=True)
# Out:
# Training model for noise level 0
# Finishing previous runs because reinit is set to 'default'.
# ...

# %% [markdown]
# ## Results

# %% [markdown]
# ### write gaussian sampled training results

# %%
import glob
std,nn = 1,5
path_checkpoints = glob.glob(f'/home/xinqiao/new_mount/gaussian_sampler/toy_dataset/max_norm/*_gaussian_std:{std}_nn:{nn}/checkpoints/*/*epoch:0050*')
path_checkpoints.sort()
path_checkpoints
# Out:
# ['/home/xinqiao/new_mount/gaussian_sampler/toy_dataset/max_norm/00_gaussian_std:1_nn:5/checkpoints/00_01.000_sample_rate/(2026-02-05, 19:24:13)_epoch:0050_lr:0.00001_trainloss:0.0006.pkl',
#  '/home/xinqiao/new_mount/gaussian_sampler/toy_dataset/max_norm/00_gaussian_std:1_nn:5/checkpoints/00_01.000_sample_rate/(2026-02-05, 23:23:37)_epoch:0050_lr:0.00001_trainloss:0.0003.pkl',
#  '/home/xinqiao/new_mount/gaussian_sampler/toy_dataset/max_norm/01_gaussian_std:1_nn:5/checkpoints/01_00.794_sample_rate/(2026-02-05, 19:27:36)_epoch:0050_lr:0.00001_trainloss:0.0043.pkl',
#  '/home/xinqiao/new_mount/gaussian_sampler/toy_dataset/max_norm/01_gaussian_std:1_nn:5/checkpoints/01_00.794_sample_rate/(2026-02-05, 23:27:00)_epoch:0050_lr:0.00001_trainloss:0.0043.pkl',
#  '/home/xinqiao/new_mount/gaussian_sampler/toy_dataset/max_norm/02_gaussian_std:1_nn:5/checkpoints/02_00.631_sample_rate/(2026-02-05, 19:31:00)_epoch:0050_lr:0.00001_trainloss:0.0046.pkl',
# ...

# %%
from Gaussian_Sampler.data.datasets import Poisson_Sampled_PV_Embeddings

for p,path in enumerate(path_checkpoints):
    # if p>=4: continue
    print(f"{p}: {path}")
    emb_dset = Poisson_Sampled_PV_Embeddings(model, dset, path)
    emb_dset.write_embeddings()
# Out:
# 0: /home/xinqiao/new_mount/gaussian_sampler/toy_dataset/max_norm/gaussian_sampler_std_5_neighbors_20/checkpoints/00_01.000_sample_rate/(2026-02-02, 17:00:17)_epoch:0050_lr:0.00001_trainloss:0.0002.pkl
# 100%|██████████| 100/100 [00:05<00:00, 16.86it/s]
# 1: /home/xinqiao/new_mount/gaussian_sampler/toy_dataset/max_norm/gaussian_sampler_std_5_neighbors_20/checkpoints/01_00.785_sample_rate/(2026-02-02, 17:03:52)_epoch:0050_lr:0.00001_trainloss:0.0008.pkl
# 100%|██████████| 100/100 [00:05<00:00, 18.06it/s]
# 2: /home/xinqiao/new_mount/gaussian_sampler/toy_dataset/max_norm/gaussian_sampler_std_5_neighbors_20/checkpoints/02_00.616_sample_rate/(2026-02-02, 17:07:26)_epoch:0050_lr:0.00001_trainloss:0.0008.pkl
# 100%|██████████| 100/100 [00:05<00:00, 19.21it/s]
# 3: /home/xinqiao/new_mount/gaussian_sampler/toy_dataset/max_norm/gaussian_sampler_std_5_neighbors_20/checkpoints/03_00.483_sample_rate/(2026-02-02, 17:11:03)_epoch:0050_lr:0.00001_trainloss:0.0009.pkl
# ...

# %% [markdown]
# ### write gaussian sampled training results

# %%
import glob
path_checkpoints = glob.glob('/home/xinqiao/new_mount/gaussian_sampler/toy_dataset/max_norm/gaussian_sampler/checkpoints/*/*epoch:0050*')
path_checkpoints.sort()
path_checkpoints
# Out:
# ['/home/xinqiao/new_mount/gaussian_sampler/toy_dataset/max_norm/gaussian_sampler/checkpoints/00_01.000_sample_rate/(2026-01-27, 13:23:52)_epoch:0050_lr:0.00001_trainloss:0.0002.pkl',
#  '/home/xinqiao/new_mount/gaussian_sampler/toy_dataset/max_norm/gaussian_sampler/checkpoints/01_00.785_sample_rate/(2026-01-27, 13:27:16)_epoch:0050_lr:0.00001_trainloss:0.0014.pkl',
#  '/home/xinqiao/new_mount/gaussian_sampler/toy_dataset/max_norm/gaussian_sampler/checkpoints/02_00.616_sample_rate/(2026-01-27, 13:30:41)_epoch:0050_lr:0.00001_trainloss:0.0015.pkl',
#  '/home/xinqiao/new_mount/gaussian_sampler/toy_dataset/max_norm/gaussian_sampler/checkpoints/03_00.483_sample_rate/(2026-01-27, 13:34:02)_epoch:0050_lr:0.00001_trainloss:0.0017.pkl',
#  '/home/xinqiao/new_mount/gaussian_sampler/toy_dataset/max_norm/gaussian_sampler/checkpoints/04_00.379_sample_rate/(2026-01-27, 13:38:53)_epoch:0050_lr:0.00001_trainloss:0.0018.pkl',
# ...

# %%
from Gaussian_Sampler.data.datasets import Poisson_Sampled_PV_Embeddings

for p,path in enumerate(path_checkpoints):
    # if p>=4: continue
    print(f"{p}: {path}")
    emb_dset = Poisson_Sampled_PV_Embeddings(model, dset, path)
    emb_dset.write_embeddings()
# Out:
# 0: /home/xinqiao/new_mount/gaussian_sampler/toy_dataset/max_norm/gaussian_sampler/checkpoints/00_01.000_sample_rate/(2026-01-27, 13:23:52)_epoch:0050_lr:0.00001_trainloss:0.0002.pkl
# 100%|██████████| 100/100 [00:05<00:00, 18.81it/s]
# 1: /home/xinqiao/new_mount/gaussian_sampler/toy_dataset/max_norm/gaussian_sampler/checkpoints/01_00.785_sample_rate/(2026-01-27, 13:27:16)_epoch:0050_lr:0.00001_trainloss:0.0014.pkl
# 100%|██████████| 100/100 [00:05<00:00, 18.71it/s]
# 2: /home/xinqiao/new_mount/gaussian_sampler/toy_dataset/max_norm/gaussian_sampler/checkpoints/02_00.616_sample_rate/(2026-01-27, 13:30:41)_epoch:0050_lr:0.00001_trainloss:0.0015.pkl
# 100%|██████████| 100/100 [00:05<00:00, 18.24it/s]
# 3: /home/xinqiao/new_mount/gaussian_sampler/toy_dataset/max_norm/gaussian_sampler/checkpoints/03_00.483_sample_rate/(2026-01-27, 13:34:02)_epoch:0050_lr:0.00001_trainloss:0.0017.pkl
# 100%|██████████| 100/100 [00:05<00:00, 19.46it/s]

# %% [markdown]
# ### write random sampled training results

# %%
import glob
path_checkpoints = glob.glob('/home/xinqiao/new_mount/gaussian_sampler/toy_dataset/max_norm/random_sampler/checkpoints/*/*epoch:0050*')

# %%
from Gaussian_Sampler.data.datasets import Poisson_Sampled_PV_Embeddings

for p,path in enumerate(path_checkpoints):
    print(path)
    emb_dset = Poisson_Sampled_PV_Embeddings(model, dset)
    model.load_weights(path)
    emb_dset.write_embeddings(noise_level=p)
# Out:
# /home/xinqiao/new_mount/gaussian_sampler/toy_dataset/max_norm/random_sampler/checkpoints/13_00.043_sample_rate/(2026-01-27, 15:51:53)_epoch:0050_lr:0.00001_trainloss:0.0229.pkl
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 5
#       3 for p,path in enumerate(path_checkpoints):
#       4     print(path)
# ----> 5     emb_dset = Poisson_Sampled_PV_Embeddings(model, dset)
#       6     model.load_weights(path)
#       7     emb_dset.write_embeddings(noise_level=p)
#
# TypeError: Poisson_Sampled_PV_Embeddings.__init__() missing 1 required positional argument: 'checkpoint'

# %% [markdown]
# ## Visualize training results

# %%
# path_checkpoint = '/home/xinqiao/new_mount/gaussian_sampler/toy_dataset/max_norm/checkpoints/00_01.000_sample_rate/(2026-01-21, 15:04:47)_epoch:0020_lr:0.00001_trainloss:0.0020.pkl' 

# model.load_weights(path_checkpoint)

# %%
from Gaussian_Sampler.data.datasets import Poisson_Sampled_PV_Embeddings
# path_checkpoints = glob.glob('/home/xinqiao/new_mount/gaussian_sampler/toy_dataset/max_norm/gaussian_sampler_std_5_neighbors_20/checkpoints/*/*epoch:0050*')
path_checkpoints = glob.glob('/home/xinqiao/new_mount/gaussian_sampler/toy_dataset/max_norm/gaussian_sampler/checkpoints/*/*epoch:0050*')
# path_checkpoints = glob.glob('/home/xinqiao/new_mount/gaussian_sampler/toy_dataset/max_norm/random_sampler/checkpoints/*/*epoch:0050*')
path_checkpoints.sort()
path = path_checkpoints[0]

emb_dset = Poisson_Sampled_PV_Embeddings(model, dset, path)

# %%
from Gaussian_Sampler.viz.plotly_viz import Poisson_Sampled_PV_viz_embeddings
emb_viz = Poisson_Sampled_PV_viz_embeddings(model, emb_dset, dset, path_checkpoints)

# %% [markdown]
# ### single fit

# %%
emb_viz.layout_fits_params()
# Out:
# /home/xinqiao/new_mount/gaussian_sampler/Gaussian_Sampler/Notebooks/../Gaussian_Sampler/viz/plotly_viz.py:400: RuntimeWarning:
#
# invalid value encountered in divide
# ...

# %% [markdown]
# ### batches

# %%
emb_viz.layout_batch_fits_params()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 emb_viz.layout_batch_fits()
#       2 #TODO: be able to pan, scroll, and click and zoom.
#       3 #TODO: Make a version without the batching
#       4 #TODO: why is the fit so small?
#
# File ~/new_mount/gaussian_sampler/Gaussian_Sampler/Notebooks/../Gaussian_Sampler/viz/plotly_viz.py:754, in Poisson_Sampled_PV_viz_embeddings.layout_batch_fits(self)
#     751 def layout_batch_fits(self):
#     752     # Initialize batch figures from parent
#     753     if not hasattr(self, 'batch_img_fig') or len(self.batch_img_fig.data) == 0:
# --> 754         self._init_batch_figures()
#     756     # Initialize fits figures
#     757     self._init_fits_figures()
#
# ...

# %% [markdown]
# ## Design
